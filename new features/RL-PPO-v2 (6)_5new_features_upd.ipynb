# %% [markdown]
# ### PPO AGENT:

# %% [markdown]
# #### Load the dataset and preprocess the dataframe in the required format.

# %% [markdown]
# Technical indicators created for the environment include:
#
# - RSI
# - MACD
# - Stoch_k
# - OBV
# - Upper_BB
# - ATR_1
# - ATR_2
# - ATR_5
# - ATR_10
# - ATR_20

# %% [markdown]
# Additional features:
#
# - Liquidity Shock: measures the sudden change of market liquidity.
# - VWAP Deviation: the deviation of current price from VWAP.
# - Institutional Activity Ratio: the ratio of large trades (indicative of institutional activity) to total trades.
# - Smoothed Order Flow Imbalance: Order Flow Imbalance measures the difference between buy and sell orders. But here we will reduce the volatility by rolling it.
# - Volume Spike: indicates sudden increases in trading volume compared to a rolling average.

# %%
import pandas as pd
import numpy as np
import talib as ta

class TechnicalIndicators:
    def __init__(self, data):
        self.data = data
    
    def add_momentum_indicators(self):
        self.data['RSI'] = ta.RSI(self.data['Close'], timeperiod=14)
        self.data['MACD'], self.data['MACD_signal'], self.data['MACD_hist'] = ta.MACD(self.data['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
        self.data['Stoch_k'], self.data['Stoch_d'] = ta.STOCH(self.data['High'], self.data['Low'], self.data['Close'],
                                                              fastk_period=14, slowk_period=3, slowd_period=3)
        
    def add_volume_indicators(self):
        self.data['OBV'] = ta.OBV(self.data['Close'], self.data['Volume'])
        self.data['AD'] = ta.AD(self.data['High'], self.data['Low'], self.data['Close'], self.data['Volume'])

    def add_volatility_indicators(self):
        self.data['Upper_BB'], self.data['Middle_BB'], self.data['Lower_BB'] = ta.BBANDS(self.data['Close'], timeperiod=20)
        self.data['ATR_1'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=1)
        self.data['ATR_2'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=2)
        self.data['ATR_5'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=5)
        self.data['ATR_10'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=10)
        self.data['ATR_20'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=20)

    def add_trend_indicators(self):
        self.data['ADX'] = ta.ADX(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=14)
        self.data['+DI'] = ta.PLUS_DI(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=14)
        self.data['-DI'] = ta.MINUS_DI(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=14)
        self.data['CCI'] = ta.CCI(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=5)

    def add_other_indicators(self):
        self.data['DLR'] = np.log(self.data['Close'] / self.data['Close'].shift(1))
        self.data['TWAP'] = self.data['Close'].expanding().mean()
        self.data['VWAP'] = (self.data['Volume'] * (self.data['High'] + self.data['Low']) / 2).cumsum() / self.data['Volume'].cumsum()
    
    
    # define 5 new features
    def calculate_new5_features(self):
        
        self.data['liquidity'] = self.data['bid_sz_00'] * self.data['bid_px_00'] + self.data['ask_sz_00'] * self.data['ask_px_00']
        #1. Liquidity Shock Indicator
        self.data['Liquidity_Shock'] = self.data['liquidity'].pct_change()
        self.data['Liquidity_Shock'].fillna(0, inplace=True)  # Replace NaN values with 0
    
        #2. VWAP Deviation
        self.data['VWAP_Deviation'] = (self.data['price'] - self.data['VWAP']) / self.data['VWAP']
        self.data['VWAP_Deviation'].fillna(0, inplace=True)

        #3. Trading Volume Spike
        self.data['Volume_Spike'] = (self.data['Volume'] - self.data['Volume'].rolling(window=20).mean()) / (self.data['Volume'].rolling(window=20).mean())
        self.data['Volume_Spike'].fillna(0, inplace=True)

        #4. Institutional Activity Ratio
        large_trade_threshold = self.data['Volume'].quantile(0.9)  # Define a threshold for large trades
        self.data['Institutional_Activity_Ratio'] = self.data['Volume'].apply(lambda x: 1 if x > large_trade_threshold else 0).rolling(window=10).mean()
        self.data['Institutional_Activity_Ratio'].fillna(0, inplace=True)

        #5. Customized(Smoothed) Order Flow Imbalance
        self.data['Order_Flow_Imbalance'] = self.data['size'].where(self.data['side'] == 'B', 0).cumsum() - self.data['size'].where(self.data['side'] == 'A', 0).cumsum()
        # Apply rolling window to smooth OFI
        self.data['smoothed_ofi'] = self.data['Order_Flow_Imbalance'].rolling(window=10).mean()
        self.data['smoothed_ofi'].fillna(0, inplace=True)

    
    def add_all_indicators(self):
        self.add_momentum_indicators()
        self.add_volume_indicators()
        self.add_volatility_indicators()
        self.add_trend_indicators()
        self.add_other_indicators()
        self.calculate_new5_features()
        return self.data
# Out:
# /Users/gracielagao/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_csv('xnas-itch-20230703.tbbo.csv')

# Preprocessing to create necessary columns
data['price']=data['price']/1e9
data['bid_px_00']=data['bid_px_00']/1e9
data['ask_px_00']=data['ask_px_00']/1e9

data['Close'] = data['price']
data['Volume'] = data['size']
data['High'] = data[['bid_px_00', 'ask_px_00']].max(axis=1)
data['Low'] = data[['bid_px_00', 'ask_px_00']].min(axis=1)
data['Open'] = data['Close'].shift(1).fillna(data['Close'])


ti = TechnicalIndicators(data)
df_with_indicators = ti.add_all_indicators()
market_features_df = df_with_indicators[35:]
# Out:
# /var/folders/zg/_fv5_v7d7pzfys34w924vkqw0000gn/T/ipykernel_5840/3477555257.py:45: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['Liquidity_Shock'].fillna(0, inplace=True)  # Replace NaN values with 0
# /var/folders/zg/_fv5_v7d7pzfys34w924vkqw0000gn/T/ipykernel_5840/3477555257.py:49: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['VWAP_Deviation'].fillna(0, inplace=True)
# /var/folders/zg/_fv5_v7d7pzfys34w924vkqw0000gn/T/ipykernel_5840/3477555257.py:53: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['Volume_Spike'].fillna(0, inplace=True)
# /var/folders/zg/_fv5_v7d7pzfys34w924vkqw0000gn/T/ipykernel_5840/3477555257.py:58: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['Institutional_Activity_Ratio'].fillna(0, inplace=True)
# /var/folders/zg/_fv5_v7d7pzfys34w924vkqw0000gn/T/ipykernel_5840/3477555257.py:64: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['smoothed_ofi'].fillna(0, inplace=True)

# %% [markdown]
# Checking the dataset:

# %%
# Show all columns in pandas
pd.set_option('display.max_columns', None)

market_features_df.head(35)
# Out:
#                 ts_recv             ts_event  rtype  publisher_id  \
# 35  1688371214386057385  1688371214385893078      1             2
# 36  1688371214386063777  1688371214385899379      1             2
# 37  1688371215804852019  1688371215804687301      1             2
# 38  1688371219671476629  1688371219671312224      1             2
# 39  1688371223368835585  1688371223368671235      1             2
# 40  1688371229849940201  1688371229849775570      1             2
# 41  1688371230451172473  1688371230451005195      1             2
# 42  1688371230451172473  1688371230451005195      1             2
# 43  1688371230451172473  1688371230451005195      1             2
# 44  1688371230451995982  1688371230451829005      1             2
# 45  1688371230451995982  1688371230451829005      1             2
# 46  1688371230451995982  1688371230451829005      1             2
# 47  1688371230451995982  1688371230451829005      1             2
# 48  1688371230566546422  1688371230566381995      1             2
# 49  1688371237858109689  1688371237857944791      1             2
# 50  1688371242324266534  1688371242324101963      1             2
# 51  1688371247317894640  1688371247317729998      1             2
# 52  1688371257325756491  1688371257325590403      1             2
# 53  1688371257325756491  1688371257325590403      1             2
# 54  1688371259762706298  1688371259762541862      1             2
# 55  1688371259998644855  1688371259998480243      1             2
# 56  1688371262030749190  1688371262030585068      1             2
# 57  1688371262738878803  1688371262738714506      1             2
# 58  1688371262738976817  1688371262738812696      1             2
# 59  1688371262739005935  1688371262738841844      1             2
# 60  1688371262739229179  1688371262739065129      1             2
# 61  1688371262739239338  1688371262739074592      1             2
# 62  1688371270151139658  1688371270150974638      1             2
# 63  1688371271298128899  1688371271297964469      1             2
# 64  1688371271609555288  1688371271609390022      1             2
# 65  1688371272249175548  1688371272249009974      1             2
# 66  1688371272249760640  1688371272249596259      1             2
# 67  1688371272250210772  1688371272250045693      1             2
# 68  1688371272250210772  1688371272250045693      1             2
# 69  1688371272377490201  1688371272377325167      1             2
#
#     instrument_id action side  depth   price  size  flags  ts_in_delta  \
# 35             32      T    N      0  194.05    50    130       164307
# 36             32      T    N      0  194.05    50    130       164398
# 37             32      T    B      0  194.21    10    130       164718
# 38             32      T    N      0  194.14    10    130       164405
# 39             32      T    B      0  194.13    10    130       164350
# 40             32      T    B      0  194.13   100    130       164631
# 41             32      T    N      0  194.02    10      0       167278
# 42             32      T    A      0  194.01     1      0       167278
# 43             32      T    A      0  194.01   100    130       167278
# 44             32      T    A      0  194.00  3075      0       166977
# 45             32      T    A      0  194.00     4      0       166977
# 46             32      T    A      0  194.00     5      0       166977
# 47             32      T    A      0  194.00    16    130       166977
# 48             32      T    N      0  194.09    10    130       164427
# 49             32      T    B      0  194.12    10    130       164898
# 50             32      T    B      0  194.15    10    130       164571
# 51             32      T    B      0  194.10    10    130       164642
# 52             32      T    A      0  194.10     1      0       166088
# 53             32      T    A      0  194.10     1    130       166088
# 54             32      T    B      0  194.12    50    130       164436
# 55             32      T    B      0  194.12     4    130       164612
# 56             32      T    B      0  194.12     3    130       164122
# 57             32      T    B      0  194.12    75    130       164297
# 58             32      T    B      0  194.12    18    130       164121
# 59             32      T    B      0  194.12    10    130       164091
# 60             32      T    B      0  194.12    75    130       164050
# 61             32      T    B      0  194.12     9    130       164746
# 62             32      T    B      0  194.18     1    130       165020
# 63             32      T    B      0  194.18     2    130       164430
# 64             32      T    B      0  194.18     1    130       165266
# 65             32      T    B      0  194.18     6    130       165574
# 66             32      T    B      0  194.20     1    130       164381
# 67             32      T    B      0  194.26     9      0       165079
# 68             32      T    B      0  194.26    50    130       165079
# 69             32      T    N      0  194.28     1    130       165034
#
#     sequence  bid_px_00  ask_px_00  bid_sz_00  ask_sz_00  bid_ct_00  \
# 35    326232     194.00     194.30       3101         19          4
# 36    326233     194.00     194.30       3101         19          4
# 37    328131     194.00     194.21       3101         29          4
# 38    331406     194.00     194.16       3101        400          4
# 39    334235     194.00     194.13       3101        400          4
# 40    339055     194.01     194.13        101        390          2
# 41    339547     194.01     194.16        101        400          2
# 42    339548     194.01     194.16        101        400          2
# 43    339549     194.01     194.16        100        400          1
# 44    339553     194.00     194.16       3119        400          5
# 45    339554     194.00     194.16         44        400          4
# 46    339555     194.00     194.16         40        400          3
# 47    339556     194.00     194.16         35        400          2
# 48    339623     194.00     194.16         19        400          2
# 49    346965     194.02     194.12         80        400          1
# 50    350459     194.02     194.15        180        400          2
# 51    354918     194.06     194.10        100         10          1
# 52    363515     194.10     194.12        101        244          2
# 53    363516     194.10     194.12        100        244          1
# 54    366351     194.10     194.12         99        244          1
# 55    367018     194.10     194.12         99        194          1
# 56    370717     194.11     194.12        200        190          1
# 57    372529     194.11     194.12        200        187          1
# 58    372534     194.11     194.12        200        112          1
# 59    372547     194.11     194.12        200         94          1
# 60    372566     194.11     194.12        200         84          1
# 61    372567     194.11     194.12        200          9          1
# 62    378624     194.11     194.18        200         10          1
# 63    379579     194.12     194.18          1          9          1
# 64    380000     194.12     194.18          3          7          1
# 65    380446     194.15     194.18         99          6          1
# 66    380449     194.15     194.20         99          1          1
# 67    380450     194.15     194.26         99         59          1
# 68    380451     194.15     194.26         99         50          1
# 69    380534     194.15     194.29         99        400          1
#
#     ask_ct_00 symbol   Close  Volume    High     Low    Open        RSI  \
# 35         10   AAPL  194.05      50  194.30  194.00  194.05  54.544543
# 36         10   AAPL  194.05      50  194.30  194.00  194.05  54.544543
# 37          1   AAPL  194.21      10  194.21  194.00  194.05  85.890753
# 38          1   AAPL  194.14      10  194.16  194.00  194.21  64.827662
# 39          1   AAPL  194.13      10  194.13  194.00  194.14  62.470772
# 40          1   AAPL  194.13     100  194.13  194.01  194.13  62.470772
# 41          1   AAPL  194.02      10  194.16  194.01  194.13  42.676806
# 42          1   AAPL  194.01       1  194.16  194.01  194.02  41.392784
# 43          1   AAPL  194.01     100  194.16  194.01  194.01  41.392784
# 44          1   AAPL  194.00    3075  194.16  194.00  194.01  39.997126
# 45          1   AAPL  194.00       4  194.16  194.00  194.00  39.997126
# 46          1   AAPL  194.00       5  194.16  194.00  194.00  39.997126
# 47          1   AAPL  194.00      16  194.16  194.00  194.00  39.997126
# 48          1   AAPL  194.09      10  194.16  194.00  194.00  57.389307
# 49          1   AAPL  194.12      10  194.12  194.02  194.09  61.405134
# 50          1   AAPL  194.15      10  194.15  194.02  194.12  64.961352
# 51          1   AAPL  194.10      10  194.10  194.06  194.15  55.742466
# 52          1   AAPL  194.10       1  194.12  194.10  194.10  55.742466
# 53          1   AAPL  194.10       1  194.12  194.10  194.10  55.742466
# 54          1   AAPL  194.12      50  194.12  194.10  194.10  58.672524
# 55          1   AAPL  194.12       4  194.12  194.10  194.12  58.672524
# 56          1   AAPL  194.12       3  194.12  194.11  194.12  58.672524
# 57          1   AAPL  194.12      75  194.12  194.11  194.12  58.672524
# 58          1   AAPL  194.12      18  194.12  194.11  194.12  58.672524
# 59          1   AAPL  194.12      10  194.12  194.11  194.12  58.672524
# 60          1   AAPL  194.12      75  194.12  194.11  194.12  58.672524
# 61          1   AAPL  194.12       9  194.12  194.11  194.12  58.672524
# 62          1   AAPL  194.18       1  194.18  194.11  194.12  69.597068
# 63          1   AAPL  194.18       2  194.18  194.12  194.18  69.597068
# 64          1   AAPL  194.18       1  194.18  194.12  194.18  69.597068
# 65          1   AAPL  194.18       6  194.18  194.15  194.18  69.597068
# 66          1   AAPL  194.20       1  194.20  194.15  194.18  72.818542
# 67          2   AAPL  194.26       9  194.26  194.15  194.20  79.750541
# 68          1   AAPL  194.26      50  194.26  194.15  194.26  79.750541
# 69          1   AAPL  194.28       1  194.29  194.15  194.26  81.567778
#
#         MACD  MACD_signal  MACD_hist       Stoch_k     Stoch_d     OBV  \
# 35  0.006271    -0.003130   0.009401  5.252525e+01   61.952862  -266.0
# 36  0.007108    -0.001082   0.008190  3.838384e+01   52.525253  -266.0
# 37  0.020446     0.003223   0.017223  4.040404e+01   43.771044  -256.0
# 38  0.025079     0.007594   0.017484  4.949495e+01   42.760943  -266.0
# 39  0.027625     0.011601   0.016025  5.757576e+01   49.158249  -276.0
# 40  0.029305     0.015141   0.014164  4.949495e+01   52.188552  -276.0
# 41  0.021513     0.016416   0.005097  3.454545e+01   47.205387  -286.0
# 42  0.014365     0.016006  -0.001641  1.949495e+01   34.511785  -287.0
# 43  0.008601     0.014525  -0.005924  4.444444e+00   19.494949  -287.0
# 44  0.003189     0.012257  -0.009069  2.222222e+00    8.720539 -3362.0
# 45 -0.001087     0.009588  -0.010676  1.111111e+00    2.592593 -3362.0
# 46 -0.004425     0.006786  -0.011211 -4.736952e-15    1.111111 -3362.0
# 47 -0.006990     0.004030  -0.011021 -4.736952e-15    0.370370 -3362.0
# 48 -0.001741     0.002876  -0.004617  1.000000e+01    3.333333 -3352.0
# 49  0.004785     0.003258   0.001527  2.333333e+01   11.111111 -3342.0
# 50  0.012237     0.005054   0.007183  4.714286e+01   26.825397 -3332.0
# 51  0.013947     0.006833   0.007115  5.797619e+01   42.817460 -3342.0
# 52  0.015128     0.008492   0.006636  6.547619e+01   56.865079 -3342.0
# 53  0.015881     0.009969   0.005911  6.250000e+01   61.984127 -3342.0
# 54  0.017885     0.011553   0.006332  6.666667e+01   64.880952 -3292.0
# 55  0.019251     0.013092   0.006159  7.083333e+01   66.666667 -3292.0
# 56  0.020103     0.014494   0.005608  7.500000e+01   70.833333 -3292.0
# 57  0.020540     0.015704   0.004837  7.500000e+01   73.611111 -3292.0
# 58  0.020649     0.016693   0.003957  7.500000e+01   75.000000 -3292.0
# 59  0.020499     0.017454   0.003045  7.500000e+01   75.000000 -3292.0
# 60  0.020148     0.017993   0.002155  7.500000e+01   75.000000 -3292.0
# 61  0.019644     0.018323   0.001321  7.500000e+01   75.000000 -3292.0
# 62  0.023811     0.019421   0.004390  8.333333e+01   77.777778 -3291.0
# 63  0.026804     0.020897   0.005907  9.166667e+01   83.333333 -3291.0
# 64  0.028844     0.022487   0.006357  1.000000e+02   91.666667 -3291.0
# 65  0.030113     0.024012   0.006101  1.000000e+02   97.222222 -3291.0
# 66  0.032360     0.025682   0.006679  1.000000e+02  100.000000 -3290.0
# 67  0.038538     0.028253   0.010285  1.000000e+02  100.000000 -3281.0
# 68  0.042939     0.031190   0.011749  1.000000e+02  100.000000 -3281.0
# 69  0.047493     0.034451   0.013043  9.814815e+01   99.382716 -3280.0
#
#              AD    Upper_BB  Middle_BB    Lower_BB  ATR_1     ATR_2     ATR_5  \
# 35  -392.666667  194.065621   194.0170  193.968379   0.30  0.175078  0.098615
# 36  -426.000000  194.068990   194.0200  193.971010   0.30  0.237539  0.138892
# 37  -416.000000  194.125889   194.0305  193.935111   0.21  0.223770  0.153114
# 38  -408.500000  194.142928   194.0375  193.932072   0.21  0.216885  0.164491
# 39  -398.500000  194.155247   194.0440  193.932753   0.14  0.178442  0.159593
# 40  -298.500000  194.165821   194.0505  193.935179   0.12  0.149221  0.151674
# 41  -307.166667  194.165390   194.0515  193.937610   0.15  0.149611  0.151339
# 42  -308.166667  194.165066   194.0520  193.938934   0.15  0.149805  0.151071
# 43  -408.166667  194.164727   194.0525  193.940273   0.15  0.149903  0.150857
# 44 -3483.166667  194.164727   194.0525  193.940273   0.16  0.154951  0.152686
# 45 -3487.166667  194.164727   194.0525  193.940273   0.16  0.157476  0.154149
# 46 -3492.166667  194.164727   194.0525  193.940273   0.16  0.158738  0.155319
# 47 -3508.166667  194.164727   194.0525  193.940273   0.16  0.159369  0.156255
# 48 -3506.916667  194.167653   194.0570  193.946347   0.16  0.159684  0.157004
# 49 -3496.916667  194.174425   194.0605  193.946575   0.10  0.129842  0.145603
# 50 -3486.916667  194.185746   194.0655  193.945254   0.13  0.129921  0.142483
# 51 -3476.916667  194.188930   194.0680  193.947070   0.09  0.109961  0.131986
# 52 -3477.916667  194.191904   194.0705  193.949096   0.02  0.064980  0.109589
# 53 -3478.916667  194.194672   194.0730  193.951328   0.02  0.042490  0.091671
# 54 -3428.916667  194.199345   194.0765  193.953655   0.02  0.031245  0.077337
# 55 -3424.916667  194.203612   194.0800  193.956388   0.02  0.025623  0.065870
# 56 -3421.916667  194.207480   194.0835  193.959520   0.01  0.017811  0.054696
# 57 -3346.916667  194.190158   194.0790  193.967842   0.01  0.013906  0.045756
# 58 -3328.916667  194.187289   194.0780  193.968711   0.01  0.011953  0.038605
# 59 -3318.916667  194.185920   194.0775  193.969080   0.01  0.010976  0.032884
# 60 -3243.916667  194.184536   194.0770  193.969464   0.01  0.010488  0.028307
# 61 -3234.916667  194.187754   194.0820  193.976246   0.01  0.010244  0.024646
# 62 -3233.916667  194.199031   194.0905  193.981969   0.07  0.040122  0.033717
# 63 -3231.916667  194.207609   194.0990  193.990391   0.06  0.050061  0.038973
# 64 -3230.916667  194.212038   194.1080  194.003962   0.06  0.055031  0.043179
# 65 -3224.916667  194.212937   194.1170  194.021063   0.03  0.042515  0.040543
# 66 -3223.916667  194.213279   194.1270  194.040721   0.05  0.046258  0.042434
# 67 -3214.916667  194.224143   194.1400  194.055857   0.11  0.078129  0.055947
# 68 -3164.916667  194.244265   194.1485  194.052735   0.11  0.094064  0.066758
# 69 -3164.059524  194.267003   194.1565  194.045997   0.14  0.117032  0.081406
#
#       ATR_10    ATR_20        ADX        +DI       -DI         CCI       DLR  \
# 35  0.075141  0.072403  97.257397  30.435801  0.196362  166.666667  0.000000
# 36  0.097627  0.083783  97.361721  22.989295  0.148320   83.333333  0.000000
# 37  0.108864  0.090094  97.458593  19.409454  0.125224   79.268293  0.000824
# 38  0.118978  0.096089  97.548546  16.622008  0.107240   -3.205128 -0.000360
# 39  0.121080  0.098285  97.632074  15.068361  0.097216 -113.095238 -0.000052
# 40  0.120972  0.099370  97.709636  13.871534  0.089495  -64.102564  0.000000
# 41  0.123875  0.101902  97.793820  14.463498  0.080850 -113.425926 -0.000567
# 42  0.126487  0.104307  97.871992  13.100725  0.073232  -90.909091 -0.000052
# 43  0.128839  0.106591  97.944580  11.893862  0.066486  -61.224490  0.000000
# 44  0.131955  0.109262  97.267563  10.755675  0.658220  -81.081081 -0.000052
# 45  0.134759  0.111799  96.638905   9.750792  0.596723  -83.333333  0.000000
# 46  0.137283  0.114209  96.055151   8.859404  0.542173  -55.555556  0.000000
# 47  0.139555  0.116498  95.513093   8.065375  0.493580  -41.666667  0.000000
# 48  0.141600  0.118673  95.009754   7.355430  0.450133  166.666667  0.000464
# 49  0.137440  0.117740  94.542368   6.944020  0.424956   90.643275  0.000155
# 50  0.136696  0.118353  94.270606   8.115584  0.394096  107.142857  0.000155
# 51  0.132026  0.116935  94.018256   7.698755  0.373855   18.518519 -0.000258
# 52  0.120823  0.112088  93.871355   8.819513  0.369315   83.333333  0.000000
# 53  0.110741  0.107484  93.734948   8.705674  0.364548   55.555556  0.000000
# 54  0.101667  0.103110  93.608283   8.586320  0.359550   89.743590  0.000103
# 55  0.093500  0.098954  93.490667   8.461391  0.354319   71.428571  0.000000
# 56  0.085150  0.094507  93.381451   8.395616  0.351564   95.238095  0.000000
# 57  0.077635  0.090281  93.280037   8.325915  0.348646   83.333333  0.000000
# 58  0.070872  0.086267  93.185866   8.252135  0.345556   55.555556  0.000000
# 59  0.064785  0.082454  93.098422   8.174129  0.342290   41.666667  0.000000
# 60  0.059306  0.078831  93.017224   8.091754  0.338840    0.000000  0.000000
# 61  0.054375  0.075390  92.941826   8.004880  0.335203    0.000000  0.000000
# 62  0.055938  0.075120  93.132535  13.823288  0.310105  166.666667  0.000309
# 63  0.056344  0.074364  93.309621  12.929663  0.290057   88.888889  0.000000
# 64  0.056710  0.073646  93.474059  12.088099  0.271178   59.210526  0.000000
# 65  0.054039  0.071464  93.626751  11.678789  0.261996   80.246914  0.000000
# 66  0.053635  0.070390  93.821556  13.301406  0.246985  135.416667  0.000103
# 67  0.059271  0.072371  94.094475  18.230801  0.217466  152.777778  0.000309
# 68  0.064344  0.074252  94.347900  16.151871  0.192668   83.333333  0.000000
# 69  0.071910  0.077540  94.611861  16.865129  0.166625   85.106383  0.000103
#
#           TWAP        VWAP  liquidity  Liquidity_Shock  VWAP_Deviation  \
# 35  194.020000  194.021894  605285.70        -0.004780        0.000145
# 36  194.020811  194.025188  605285.70         0.000000        0.000128
# 37  194.025789  194.025596  607226.09         0.003206        0.000950
# 38  194.028718  194.025873  679258.00         0.118625        0.000588
# 39  194.031250  194.026071  679246.00        -0.000018        0.000536
# 40  194.033659  194.028188   95305.71        -0.859689        0.000525
# 41  194.033333  194.028460   97259.01         0.020495       -0.000044
# 42  194.032791  194.028488   97259.01         0.000000       -0.000095
# 43  194.032273  194.031073   97065.00        -0.001995       -0.000109
# 44  194.031556  194.059670  682750.00         6.033946       -0.000307
# 45  194.030870  194.059686   86200.00        -0.873746       -0.000308
# 46  194.030213  194.059705   85424.00        -0.009002       -0.000308
# 47  194.029583  194.059766   84454.00        -0.011355       -0.000308
# 48  194.030816  194.059805   81350.00        -0.036754        0.000156
# 49  194.032600  194.059824   93169.60         0.145293        0.000310
# 50  194.034902  194.059871  112583.60         0.208373        0.000464
# 51  194.036154  194.059909   21347.00        -0.810390        0.000207
# 52  194.037358  194.059918   66969.38         2.137180        0.000207
# 53  194.038519  194.059928   66775.28        -0.002898        0.000206
# 54  194.040000  194.060393   66581.18        -0.002907        0.000307
# 55  194.041429  194.060430   56875.18        -0.145777        0.000307
# 56  194.042807  194.060461   75704.80         0.331069        0.000307
# 57  194.044138  194.061210   75122.44        -0.007693        0.000303
# 58  194.045424  194.061386   60563.44        -0.193804        0.000302
# 59  194.046667  194.061484   57069.28        -0.057694        0.000302
# 60  194.047869  194.062206   55128.08        -0.034015        0.000298
# 61  194.049032  194.062291   40569.08        -0.264094        0.000297
# 62  194.051111  194.062306   40763.80         0.004800        0.000606
# 63  194.053125  194.062337    1941.74        -0.952366        0.000606
# 64  194.055077  194.062353    1941.62        -0.000062        0.000606
# 65  194.056970  194.062463   20385.93         9.499444        0.000606
# 66  194.059104  194.062483   19415.05        -0.047625        0.000709
# 67  194.062059  194.062713   30682.19         0.580330        0.001017
# 68  194.064928  194.063974   28933.85        -0.056982        0.001010
# 69  194.068000  194.064001   96936.85         2.350292        0.001113
#
#     Volume_Spike  Institutional_Activity_Ratio  Order_Flow_Imbalance  \
# 35     -0.301676                           0.1                  -355
# 36     -0.313187                           0.1                  -355
# 37     -0.863481                           0.1                  -345
# 38     -0.863760                           0.0                  -345
# 39     -0.863946                           0.0                  -335
# 40      0.281230                           0.0                  -235
# 41     -0.872611                           0.0                  -235
# 42     -0.986851                           0.0                  -236
# 43      0.241465                           0.0                  -336
# 44     12.152267                           0.1                 -3411
# 45     -0.982858                           0.1                 -3415
# 46     -0.978522                           0.1                 -3420
# 47     -0.931492                           0.1                 -3436
# 48     -0.948065                           0.1                 -3436
# 49     -0.948160                           0.1                 -3426
# 50     -0.948227                           0.1                 -3416
# 51     -0.946823                           0.1                 -3406
# 52     -0.994521                           0.1                 -3407
# 53     -0.994349                           0.1                 -3408
# 54     -0.716954                           0.0                 -3358
# 55     -0.977058                           0.0                 -3354
# 56     -0.982558                           0.0                 -3351
# 57     -0.572040                           0.0                 -3276
# 58     -0.897523                           0.0                 -3258
# 59     -0.943069                           0.0                 -3248
# 60     -0.569954                           0.0                 -3173
# 61     -0.948380                           0.0                 -3164
# 62     -0.994264                           0.0                 -3163
# 63     -0.988197                           0.0                 -3161
# 64     -0.936508                           0.0                 -3160
# 65     -0.621451                           0.0                 -3154
# 66     -0.936102                           0.0                 -3153
# 67     -0.411765                           0.0                 -3144
# 68      1.890173                           0.0                 -3094
# 69     -0.940653                           0.0                 -3094
#
#     smoothed_ofi
# 35        -438.4
# 36        -481.3
# 37        -523.3
# 38        -482.3
# 39        -440.6
# 40        -389.4
# 41        -349.4
# 42        -320.7
# 43        -313.2
# 44        -618.8
# 45        -924.8
# 46       -1231.3
# 47       -1540.4
# 48       -1849.5
# 49       -2158.6
# 50       -2476.7
# 51       -2793.8
# 52       -3110.9
# 53       -3418.1
# 54       -3412.8
# 55       -3406.7
# 56       -3399.8
# 57       -3383.8
# 58       -3366.0
# 59       -3348.2
# 60       -3323.9
# 61       -3299.7
# 62       -3275.3
# 63       -3250.6
# 64       -3230.8
# 65       -3210.8
# 66       -3191.0
# 67       -3177.8
# 68       -3161.4
# 69       -3146.0

# %%
df_with_indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59271 entries, 0 to 59270
# Data columns (total 55 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ts_recv                       59271 non-null  int64
#  1   ts_event                      59271 non-null  int64
#  2   rtype                         59271 non-null  int64
#  3   publisher_id                  59271 non-null  int64
#  4   instrument_id                 59271 non-null  int64
#  5   action                        59271 non-null  object
#  6   side                          59271 non-null  object
#  7   depth                         59271 non-null  int64
#  8   price                         59271 non-null  float64
#  9   size                          59271 non-null  int64
#  10  flags                         59271 non-null  int64
#  11  ts_in_delta                   59271 non-null  int64
#  12  sequence                      59271 non-null  int64
#  13  bid_px_00                     59271 non-null  float64
#  14  ask_px_00                     59271 non-null  float64
#  15  bid_sz_00                     59271 non-null  int64
#  16  ask_sz_00                     59271 non-null  int64
#  17  bid_ct_00                     59271 non-null  int64
#  18  ask_ct_00                     59271 non-null  int64
#  19  symbol                        59271 non-null  object
#  20  Close                         59271 non-null  float64
#  21  Volume                        59271 non-null  int64
#  22  High                          59271 non-null  float64
#  23  Low                           59271 non-null  float64
#  24  Open                          59271 non-null  float64
#  25  RSI                           59257 non-null  float64
#  26  MACD                          59238 non-null  float64
#  27  MACD_signal                   59238 non-null  float64
#  28  MACD_hist                     59238 non-null  float64
#  29  Stoch_k                       59254 non-null  float64
#  30  Stoch_d                       59254 non-null  float64
#  31  OBV                           59271 non-null  float64
#  32  AD                            59271 non-null  float64
#  33  Upper_BB                      59252 non-null  float64
#  34  Middle_BB                     59252 non-null  float64
#  35  Lower_BB                      59252 non-null  float64
#  36  ATR_1                         59270 non-null  float64
#  37  ATR_2                         59269 non-null  float64
#  38  ATR_5                         59266 non-null  float64
#  39  ATR_10                        59261 non-null  float64
#  40  ATR_20                        59251 non-null  float64
#  41  ADX                           59244 non-null  float64
#  42  +DI                           59257 non-null  float64
#  43  -DI                           59257 non-null  float64
#  44  CCI                           59267 non-null  float64
#  45  DLR                           59270 non-null  float64
#  46  TWAP                          59271 non-null  float64
#  47  VWAP                          59271 non-null  float64
#  48  liquidity                     59271 non-null  float64
#  49  Liquidity_Shock               59271 non-null  float64
#  50  VWAP_Deviation                59271 non-null  float64
#  51  Volume_Spike                  59271 non-null  float64
#  52  Institutional_Activity_Ratio  59271 non-null  float64
#  53  Order_Flow_Imbalance          59271 non-null  int64
#  54  smoothed_ofi                  59271 non-null  float64
# dtypes: float64(36), int64(16), object(3)
# memory usage: 24.9+ MB

# %% [markdown]
# #### Create the Trading Environment class for the PPO Agent

# %%
import gym
from gym.wrappers import RecordVideo
from gym import spaces
import numpy as np
import pandas as pd

class TradingEnvironment(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, data, daily_trading_limit):
        super(TradingEnvironment, self).__init__()
        self.data = data
        self.daily_trading_limit = daily_trading_limit
        self.current_step = 0

        # Extract state columns
        self.state_columns = ['Close', 'Volume', 'RSI', 'MACD', 'MACD_signal', 'MACD_hist', 'Stoch_k', 'Stoch_d',
                              'OBV', 'Upper_BB', 'Middle_BB', 'Lower_BB', 'ATR_1', 'ADX', '+DI', '-DI', 'CCI',
                             'smoothed_ofi', 'Liquidity_Shock', 'VWAP_Deviation', 'Volume_Spike', 'Institutional_Activity_Ratio']

        # Initialize balance, shares held, and total shares traded
        self.balance = 10_000_000.0  # $10 million
        self.shares_held = 0
        self.total_shares_traded = 0

        # Define action space: [Hold, Buy, Sell]
        self.action_space = spaces.Discrete(3)

        # Define observation space based on state columns
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(len(self.state_columns),), dtype=np.float32
        )

    def reset(self):
        self.current_step = 0
        self.balance = 10_000_000.0  # $10 million
        self.shares_held = 0
        self.total_shares_traded = 0
        self.cumulative_reward = 0
        self.trades = []
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.state_columns].iloc[self.current_step].values

    def step(self, action):
        expected_price = self.data.iloc[self.current_step]['ask_px_00']
        actual_price = self.data.iloc[self.current_step]['price']
        transaction_time = self.data.iloc[self.current_step]['ts_in_delta']
        self._take_action(action)
        reward = 0
        
        if self.current_step >= len(self.data) - 1:
            self.current_step = 0
        if action != 0:
            transaction_cost= self._calculate_transaction_cost(self.data.iloc[self.current_step]['Volume'], 0.3, self.data['Volume'].mean())
            reward = self._calculate_reward(expected_price, actual_price, transaction_time, transaction_cost)
            self.cumulative_reward += reward
            if self.trades:
                self.trades[-1]['reward'] = reward
                self.trades[-1]['transaction_cost'] = transaction_cost
                self.trades[-1]['slippage'] = expected_price - actual_price
                self.trades[-1]['time_penalty'] = 100*transaction_time/1e9
        done = self.current_step == len(self.data) - 1
        obs = self._next_observation()
        info = {
        'step': self.current_step,
        'action': action,
        'price': actual_price,
        'shares': self.trades[-1]['shares'] if self.trades else 0
    }
        self.current_step += 1

        return obs, reward, done, info

    def _take_action(self, action):
        current_price = self.data.iloc[self.current_step]['Close']
        current_time = pd.to_datetime(self.data.iloc[self.current_step]['ts_event'])
        trade_info = {'step': self.current_step, 'timestamp': current_time, 'action': action, 'price': current_price, 'shares': 0, 'reward': 0, 'transaction_cost': 0, 'slippage': 0, 'time_penalty': 0}

        if action == 1: # and self.total_shares_traded < self.daily_trading_limit:  # Buy
            shares_bought = (self.balance * np.random.uniform(0.001, 0.005)) // current_price
            self.balance -= shares_bought * current_price
            self.shares_held += shares_bought
            self.total_shares_traded += shares_bought
            trade_info['shares'] = shares_bought
            if(shares_bought>0):
                self.trades.append(trade_info)
        elif action == 2: # and self.total_shares_traded < self.daily_trading_limit:  # Sell
            shares_sold = min((self.balance * np.random.uniform(0.001, 0.005)) // current_price, self.shares_held)
            self.balance += shares_sold * current_price
            self.shares_held -= shares_sold
            self.total_shares_traded -= shares_sold
            trade_info['shares'] = shares_sold
            if(shares_sold>0):
                self.trades.append(trade_info)

    def _calculate_reward(self, expected_price, actual_price, transaction_time, transaction_cost):
        slippage = expected_price - actual_price
        time_penalty = 100*transaction_time/1e9
        reward = - (slippage + time_penalty + transaction_cost)
        return reward
    
    def _calculate_transaction_cost(self, volume, volatility, daily_volume):
        return volatility * np.sqrt(volume / daily_volume)
    
    def run(self):
        self.reset()
        for _ in range(len(self.data)):
            self.step()
        return self.cumulative_reward, self.trades

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}')
        print(f'Balance: {self.balance}')
        print(f'Shares held: {self.shares_held}')
        print(f'Total shares traded: {self.total_shares_traded}')
        print(f'Total portfolio value: {self.balance + self.shares_held * self.data.iloc[self.current_step]["Close"]}')
        print(f'Cumulative reward: {self.cumulative_reward}')
        self.print_trades()

    def print_trades(self):
        # download all trades in a pandas dataframe using .csv
        trades_df = pd.DataFrame(self.trades)
        # Save a csv
        trades_df.to_csv('trades_ppo.csv', index=False)
        for trade in self.trades:
            print(f"Step: {trade['step']}, Timestamp: {trade['timestamp']}, Action: {trade['action']}, Price: {trade['price']}, Shares: {trade['shares']}, Reward: {trade['reward']}, Transaction Cost: {trade['transaction_cost']}, Slippage: {trade['slippage']}, Time Penalty: {trade['time_penalty']}")

# %% [markdown]
# #### Train the PPO Agent with the environment and for different tickers.

# %%
# Define the daily trading limit (total number of shares to trade per day)
daily_trading_limit = 1000

ticker = 'AAPL'  # Specify the ticker you want to trade
ticker_data = market_features_df[market_features_df['symbol'] == ticker]

env = TradingEnvironment(ticker_data, daily_trading_limit)  # Adjust window_size if needed

# %%
import pandas as pd
from stable_baselines3 import PPO

# Define the daily trading limit (total number of shares to trade per day)
daily_trading_limit = 1000

ticker = 'AAPL'  # Specify the ticker you want to trade
ticker_data = market_features_df[market_features_df['symbol'] == ticker]

# Create the trading environment
env = TradingEnvironment(ticker_data, daily_trading_limit)  # Adjust window_size if needed

# Define the best hyperparameters
best_hyperparameters = {'learning_rate': 0.0009931989008886031,'n_steps': 512,'batch_size': 128, 'gamma': 0.9916829193042708,'clip_range': 0.21127653449387027,'n_epochs': 6} # type: ignore

# Create the RL model with the best hyperparameters
model = PPO('MlpPolicy', env, verbose=1, **best_hyperparameters)

# Train the model
model.learn(total_timesteps=10000)

# Save the model
model.save("trading_agent")

# Evaluate the model
obs = env.reset()
for _ in range(len(ticker_data)):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        break

# Render the final state
env.render()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /Users/gracielagao/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ----------------------------
# | time/              |     |
# |    fps             | 673 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 512 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.015787665 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.113      |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.192       |
# |    n_updates            | 6           |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 0.895       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 662         |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.018199554 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0237      |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.0871      |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00876    |
# |    value_loss           | 0.631       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0025340016 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.0141      |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.473        |
# |    n_updates            | 18           |
# |    policy_gradient_loss | 0.00789      |
# |    value_loss           | 1.79         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.020755176 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.00879    |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.0443      |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0238     |
# |    value_loss           | 0.394       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 671         |
# |    iterations           | 6           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.022078037 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | -0.0199     |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.057       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.291       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 671       |
# |    iterations           | 7         |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 3584      |
# | train/                  |           |
# |    approx_kl            | 0.0352823 |
# |    clip_fraction        | 0.274     |
# |    clip_range           | 0.211     |
# |    entropy_loss         | -0.777    |
# |    explained_variance   | 0.000138  |
# |    learning_rate        | 0.000993  |
# |    loss                 | 0.115     |
# |    n_updates            | 36        |
# |    policy_gradient_loss | -0.0249   |
# |    value_loss           | 0.333     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 675        |
# |    iterations           | 8          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.06175205 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.211      |
# |    entropy_loss         | -0.558     |
# |    explained_variance   | 0.00238    |
# |    learning_rate        | 0.000993   |
# |    loss                 | 0.0657     |
# |    n_updates            | 42         |
# |    policy_gradient_loss | -0.0202    |
# |    value_loss           | 0.103      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 677          |
# |    iterations           | 9            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0010738515 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | 0.807        |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.235        |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 1.03         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 675           |
# |    iterations           | 10            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00017071352 |
# |    clip_fraction        | 0.0228        |
# |    clip_range           | 0.211         |
# |    entropy_loss         | -1.05         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.000993      |
# |    loss                 | 0.312         |
# |    n_updates            | 54            |
# |    policy_gradient_loss | -0.0021       |
# |    value_loss           | 3.22          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 676          |
# |    iterations           | 11           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0056223907 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.515        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00733     |
# |    value_loss           | 5.38         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 678         |
# |    iterations           | 12          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009408192 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.171       |
# |    n_updates            | 66          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 1.79        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 13          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.013046559 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.225       |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 686         |
# |    iterations           | 14          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.018053155 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.219       |
# |    n_updates            | 78          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 0.571       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 688          |
# |    iterations           | 15           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0077789323 |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.0343       |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.0165      |
# |    value_loss           | 0.183        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 16          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017464764 |
# |    clip_fraction        | 0.425       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.0537      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 0.251       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 17          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.018687245 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.0338      |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.0302     |
# |    value_loss           | 0.142       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 689        |
# |    iterations           | 18         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.00900566 |
# |    clip_fraction        | 0.147      |
# |    clip_range           | 0.211      |
# |    entropy_loss         | -0.69      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.000993   |
# |    loss                 | 0.0195     |
# |    n_updates            | 102        |
# |    policy_gradient_loss | -0.0213    |
# |    value_loss           | 0.194      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 690         |
# |    iterations           | 19          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.042398475 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.0251      |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.0292     |
# |    value_loss           | 0.283       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 691          |
# |    iterations           | 20           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0070618545 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -0.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.00898      |
# |    n_updates            | 114          |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 0.361        |
# ------------------------------------------
# Step: 1
# Balance: 818553.6300000057
# Shares held: 47577.0
# Total shares traded: 47577.0
# Total portfolio value: 10050870.480000006
# Cumulative reward: -830.6351038841417
# Step: 0, Timestamp: 2023-07-03 08:00:14.385893078, Action: 1, Price: 194.05, Shares: 234.0, Reward: -0.44602322322317267, Transaction Cost: 0.17959252322317262, Slippage: 0.25, Time Penalty: 0.0164307
# Step: 1, Timestamp: 2023-07-03 08:00:14.385899379, Action: 2, Price: 194.05, Shares: 144.0, Reward: -0.44603232322317266, Transaction Cost: 0.17959252322317262, Slippage: 0.25, Time Penalty: 0.0164398
# Step: 3, Timestamp: 2023-07-03 08:00:19.671312224, Action: 2, Price: 194.14, Shares: 90.0, Reward: -0.22749413640859975, Transaction Cost: 0.05079643640860315, Slippage: 0.1599999999999966, Time Penalty: 0.0166977
# Step: 11, Timestamp: 2023-07-03 08:00:30.451829005, Action: 1, Price: 194.0, Shares: 232.0, Reward: -0.23348984241218756, Transaction Cost: 0.056792142412190966, Slippage: 0.1599999999999966, Time Penalty: 0.0166977
# Step: 12, Timestamp: 2023-07-03 08:00:30.451829005, Action: 1, Price: 194.0, Shares: 224.0, Reward: -0.27829057281720293, Transaction Cost: 0.1015928728172063, Slippage: 0.1599999999999966, Time Penalty: 0.0166977
# Step: 13, Timestamp: 2023-07-03 08:00:30.566381995, Action: 1, Price: 194.09, Shares: 66.0, Reward: -0.16675891803553788, Transaction Cost: 0.08031621803554471, Slippage: 0.06999999999999318, Time Penalty: 0.0164427
# Step: 14, Timestamp: 2023-07-03 08:00:37.857944791, Action: 1, Price: 194.12, Shares: 184.0, Reward: -0.09680601803554471, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0164898
# Step: 16, Timestamp: 2023-07-03 08:00:47.317729998, Action: 2, Price: 194.1, Shares: 229.0, Reward: -0.09678041803554471, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0164642
# Step: 17, Timestamp: 2023-07-03 08:00:57.325590403, Action: 2, Price: 194.1, Shares: 95.0, Reward: -0.06200701820431181, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0166088
# Step: 18, Timestamp: 2023-07-03 08:00:57.325590403, Action: 2, Price: 194.1, Shares: 206.0, Reward: -0.06200701820431181, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0166088
# Step: 20, Timestamp: 2023-07-03 08:00:59.998480243, Action: 2, Price: 194.12, Shares: 62.0, Reward: -0.06725763640860315, Transaction Cost: 0.05079643640860315, Slippage: 0.0, Time Penalty: 0.0164612
# Step: 24, Timestamp: 2023-07-03 08:01:02.738841844, Action: 2, Price: 194.12, Shares: 104.0, Reward: -0.09672531803554471, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0164091
# Step: 29, Timestamp: 2023-07-03 08:01:11.609390022, Action: 2, Price: 194.18, Shares: 10.0, Reward: -0.04183631820430157, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164381
# Step: 36, Timestamp: 2023-07-03 08:01:13.529950930, Action: 1, Price: 194.22, Shares: 144.0, Reward: -0.11187051820429475, Transaction Cost: 0.025398218204301576, Slippage: 0.06999999999999318, Time Penalty: 0.0164723
# Step: 38, Timestamp: 2023-07-03 08:01:14.185830444, Action: 1, Price: 194.25, Shares: 190.0, Reward: -0.23631442322316465, Transaction Cost: 0.17959252322317262, Slippage: 0.03999999999999204, Time Penalty: 0.0167219
# Step: 47, Timestamp: 2023-07-03 08:01:33.770919150, Action: 1, Price: 194.24, Shares: 97.0, Reward: -0.08057850435155292, Transaction Cost: 0.04399100435157111, Slippage: 0.01999999999998181, Time Penalty: 0.0165875
# Step: 49, Timestamp: 2023-07-03 08:01:54.802043714, Action: 2, Price: 194.25, Shares: 54.0, Reward: -0.14594781023422126, Transaction Cost: 0.12950601023422126, Slippage: 0.0, Time Penalty: 0.0164418
# Step: 50, Timestamp: 2023-07-03 08:01:57.509373336, Action: 2, Price: 194.2, Shares: 54.0, Reward: -0.9740636592036607, Transaction Cost: 0.8976033592036584, Slippage: 0.060000000000002274, Time Penalty: 0.0164603
# Step: 51, Timestamp: 2023-07-03 08:02:21.218955018, Action: 2, Price: 194.2, Shares: 147.0, Reward: -0.041872318204301574, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164741
# Step: 52, Timestamp: 2023-07-03 08:02:23.951417907, Action: 1, Price: 194.2, Shares: 88.0, Reward: -0.27045948204301573, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0164773
# Step: 53, Timestamp: 2023-07-03 08:02:26.744084969, Action: 2, Price: 194.19, Shares: 122.0, Reward: -0.14866087497639888, Transaction Cost: 0.062212674976405695, Slippage: 0.06999999999999318, Time Penalty: 0.0164482
# Step: 54, Timestamp: 2023-07-03 08:02:38.530006625, Action: 2, Price: 194.19, Shares: 142.0, Reward: -0.16885340922580946, Transaction Cost: 0.15238930922580946, Slippage: 0.0, Time Penalty: 0.0164641
# Step: 79, Timestamp: 2023-07-03 08:04:10.234613592, Action: 1, Price: 194.2, Shares: 179.0, Reward: -0.042285918204301574, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0168877
# Step: 81, Timestamp: 2023-07-03 08:04:10.234613592, Action: 2, Price: 194.2, Shares: 141.0, Reward: -0.22938443916729198, Transaction Cost: 0.21249673916729198, Slippage: 0.0, Time Penalty: 0.0168877
# Step: 87, Timestamp: 2023-07-03 08:04:22.775930851, Action: 1, Price: 194.24, Shares: 179.0, Reward: -0.10702691803553561, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0167107
# Step: 90, Timestamp: 2023-07-03 08:04:22.775930851, Action: 2, Price: 194.25, Shares: 61.0, Reward: -0.20630322322316352, Transaction Cost: 0.17959252322317262, Slippage: 0.009999999999990905, Time Penalty: 0.0167107
# Step: 92, Timestamp: 2023-07-03 08:04:48.444245797, Action: 2, Price: 194.18, Shares: 156.0, Reward: -0.3025150174062697, Transaction Cost: 0.17596401740628445, Slippage: 0.10999999999998522, Time Penalty: 0.016551
# Step: 99, Timestamp: 2023-07-03 08:05:01.592537277, Action: 1, Price: 194.19, Shares: 176.0, Reward: -0.1224091046446277, Transaction Cost: 0.03591850464463453, Slippage: 0.06999999999999318, Time Penalty: 0.0164906
# Step: 100, Timestamp: 2023-07-03 08:05:11.513296650, Action: 2, Price: 194.21, Shares: 153.0, Reward: -0.10239330464461747, Transaction Cost: 0.03591850464463453, Slippage: 0.04999999999998295, Time Penalty: 0.0164748
# Step: 101, Timestamp: 2023-07-03 08:05:13.112414671, Action: 2, Price: 194.2, Shares: 23.0, Reward: -0.10183471820430384, Transaction Cost: 0.025398218204301576, Slippage: 0.060000000000002274, Time Penalty: 0.0164365
# Step: 102, Timestamp: 2023-07-03 08:05:13.717864037, Action: 1, Price: 194.2, Shares: 66.0, Reward: -0.152996054612907, Transaction Cost: 0.07619465461290473, Slippage: 0.060000000000002274, Time Penalty: 0.0168014
# Step: 104, Timestamp: 2023-07-03 08:05:13.717864037, Action: 2, Price: 194.14, Shares: 66.0, Reward: -0.17263501820429702, Transaction Cost: 0.025398218204301576, Slippage: 0.12999999999999545, Time Penalty: 0.0172368
# Step: 110, Timestamp: 2023-07-03 08:05:13.717864037, Action: 1, Price: 194.1, Shares: 95.0, Reward: -0.3092098130547099, Transaction Cost: 0.13197301305471332, Slippage: 0.1599999999999966, Time Penalty: 0.0172368
# Step: 111, Timestamp: 2023-07-03 08:05:24.553071027, Action: 2, Price: 194.18, Shares: 95.0, Reward: -0.09709611803554472, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0167799
# Step: 123, Timestamp: 2023-07-03 08:05:49.385289017, Action: 1, Price: 194.2, Shares: 118.0, Reward: -0.13709611803556518, Transaction Cost: 0.08031621803554471, Slippage: 0.040000000000020464, Time Penalty: 0.0167799
# Step: 124, Timestamp: 2023-07-03 08:05:50.024437448, Action: 2, Price: 194.2, Shares: 118.0, Reward: -0.23711981803553106, Transaction Cost: 0.08031621803554471, Slippage: 0.13999999999998636, Time Penalty: 0.0168036
# Step: 129, Timestamp: 2023-07-03 08:06:13.187564319, Action: 1, Price: 194.13, Shares: 69.0, Reward: -0.25532552742167824, Transaction Cost: 0.18835822742166689, Slippage: 0.05000000000001137, Time Penalty: 0.0169673
# Step: 130, Timestamp: 2023-07-03 08:06:13.187564319, Action: 2, Price: 194.1, Shares: 69.0, Reward: -0.22647331023423378, Transaction Cost: 0.12950601023422126, Slippage: 0.0800000000000125, Time Penalty: 0.0169673
# Step: 136, Timestamp: 2023-07-03 08:06:18.407946816, Action: 1, Price: 194.15, Shares: 222.0, Reward: -0.12678341803554585, Transaction Cost: 0.08031621803554471, Slippage: 0.030000000000001137, Time Penalty: 0.0164672
# Step: 137, Timestamp: 2023-07-03 08:06:18.408863244, Action: 2, Price: 194.07, Shares: 143.0, Reward: -0.3078421575185475, Transaction Cost: 0.18137955751853382, Slippage: 0.11000000000001364, Time Penalty: 0.0164626
# Step: 140, Timestamp: 2023-07-03 08:06:26.517259528, Action: 2, Price: 194.01, Shares: 79.0, Reward: -0.21748663607108148, Transaction Cost: 0.16063243607108943, Slippage: 0.03999999999999204, Time Penalty: 0.0168542
# Step: 152, Timestamp: 2023-07-03 08:06:39.826437098, Action: 1, Price: 194.0, Shares: 126.0, Reward: -0.11225241820429475, Transaction Cost: 0.025398218204301576, Slippage: 0.06999999999999318, Time Penalty: 0.0168542
# Step: 155, Timestamp: 2023-07-03 08:06:39.827771604, Action: 1, Price: 194.0, Shares: 81.0, Reward: -0.2005670848243751, Transaction Cost: 0.11358428482438193, Slippage: 0.06999999999999318, Time Penalty: 0.0169828
# Step: 157, Timestamp: 2023-07-03 08:06:39.827771604, Action: 2, Price: 194.0, Shares: 188.0, Reward: -0.17855737804102545, Transaction Cost: 0.09157457804103226, Slippage: 0.06999999999999318, Time Penalty: 0.0169828
# Step: 160, Timestamp: 2023-07-03 08:06:46.571931517, Action: 2, Price: 194.07, Shares: 19.0, Reward: -0.04182131820430157, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164231
# Step: 162, Timestamp: 2023-07-03 08:07:04.643817077, Action: 1, Price: 194.07, Shares: 157.0, Reward: -0.16047300435156542, Transaction Cost: 0.04399100435157111, Slippage: 0.09999999999999432, Time Penalty: 0.016482
# Step: 163, Timestamp: 2023-07-03 08:07:08.276481637, Action: 1, Price: 194.01, Shares: 204.0, Reward: -0.2569781180355413, Transaction Cost: 0.08031621803554471, Slippage: 0.1599999999999966, Time Penalty: 0.0166619
# Step: 164, Timestamp: 2023-07-03 08:07:08.276481637, Action: 2, Price: 194.0, Shares: 172.0, Reward: -0.22258040464462203, Transaction Cost: 0.03591850464463453, Slippage: 0.1699999999999875, Time Penalty: 0.0166619
# Step: 165, Timestamp: 2023-07-03 08:07:08.276481637, Action: 1, Price: 194.0, Shares: 144.0, Reward: -0.25849890928925656, Transaction Cost: 0.07183700928926906, Slippage: 0.1699999999999875, Time Penalty: 0.0166619
# Step: 166, Timestamp: 2023-07-03 08:07:08.277695844, Action: 2, Price: 194.0, Shares: 65.0, Reward: -0.4353155999056103, Transaction Cost: 0.24885069990562278, Slippage: 0.1699999999999875, Time Penalty: 0.0164649
# Step: 169, Timestamp: 2023-07-03 08:07:21.830530495, Action: 2, Price: 194.07, Shares: 102.0, Reward: -0.19677061803553902, Transaction Cost: 0.08031621803554471, Slippage: 0.09999999999999432, Time Penalty: 0.0164544
# Step: 170, Timestamp: 2023-07-03 08:07:21.830531823, Action: 2, Price: 194.07, Shares: 70.0, Reward: -0.15255010464462884, Transaction Cost: 0.03591850464463453, Slippage: 0.09999999999999432, Time Penalty: 0.0166316
# Step: 174, Timestamp: 2023-07-03 08:07:23.809281857, Action: 2, Price: 194.16, Shares: 69.0, Reward: -0.09367606911272636, Transaction Cost: 0.06719736911273545, Slippage: 0.009999999999990905, Time Penalty: 0.0164787
# Step: 175, Timestamp: 2023-07-03 08:07:29.602061828, Action: 2, Price: 194.16, Shares: 27.0, Reward: -0.12422051393390357, Transaction Cost: 0.10775551393390358, Slippage: 0.0, Time Penalty: 0.016465
# Step: 179, Timestamp: 2023-07-03 08:07:34.779124811, Action: 1, Price: 194.16, Shares: 82.0, Reward: -0.04184681820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164486
# Step: 183, Timestamp: 2023-07-03 08:07:40.788579522, Action: 2, Price: 194.17, Shares: 82.0, Reward: -0.10703381803556404, Transaction Cost: 0.08031621803554471, Slippage: 0.010000000000019327, Time Penalty: 0.0167176
# Step: 197, Timestamp: 2023-07-03 08:08:02.523837858, Action: 1, Price: 194.14, Shares: 229.0, Reward: -0.10703381803556404, Transaction Cost: 0.08031621803554471, Slippage: 0.010000000000019327, Time Penalty: 0.0167176
# Step: 199, Timestamp: 2023-07-03 08:08:05.494156630, Action: 2, Price: 194.07, Shares: 73.0, Reward: -0.19807737281721882, Transaction Cost: 0.1015928728172063, Slippage: 0.0800000000000125, Time Penalty: 0.0164845
# Step: 201, Timestamp: 2023-07-03 08:08:16.990744776, Action: 1, Price: 194.08, Shares: 172.0, Reward: -0.11276745461288654, Transaction Cost: 0.07619465461290473, Slippage: 0.01999999999998181, Time Penalty: 0.0165728
# Step: 202, Timestamp: 2023-07-03 08:08:24.284550456, Action: 1, Price: 194.1, Shares: 77.0, Reward: -0.04188821820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.01649
# Step: 203, Timestamp: 2023-07-03 08:08:27.782289263, Action: 2, Price: 194.1, Shares: 145.0, Reward: -0.041846318204301576, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164481
# Step: 204, Timestamp: 2023-07-03 08:08:35.298678941, Action: 2, Price: 194.07, Shares: 95.0, Reward: -0.07208021820430272, Transaction Cost: 0.025398218204301576, Slippage: 0.030000000000001137, Time Penalty: 0.016682
# Step: 207, Timestamp: 2023-07-03 08:08:35.299423264, Action: 1, Price: 194.05, Shares: 173.0, Reward: -0.1745262139338865, Transaction Cost: 0.10775551393390358, Slippage: 0.04999999999998295, Time Penalty: 0.0167707
# Step: 211, Timestamp: 2023-07-03 08:08:43.196226286, Action: 2, Price: 194.09, Shares: 227.0, Reward: -0.062382304644625436, Transaction Cost: 0.03591850464463453, Slippage: 0.009999999999990905, Time Penalty: 0.0164638
# Step: 212, Timestamp: 2023-07-03 08:08:45.366675240, Action: 2, Price: 194.08, Shares: 111.0, Reward: -0.06190911820428338, Transaction Cost: 0.025398218204301576, Slippage: 0.01999999999998181, Time Penalty: 0.0165109
# Step: 213, Timestamp: 2023-07-03 08:08:53.343838795, Action: 1, Price: 194.05, Shares: 194.0, Reward: -0.10824697804103227, Transaction Cost: 0.09157457804103226, Slippage: 0.0, Time Penalty: 0.0166724
# Step: 216, Timestamp: 2023-07-03 08:08:54.262741699, Action: 1, Price: 194.05, Shares: 231.0, Reward: -0.3204599820429987, Transaction Cost: 0.25398218204301576, Slippage: 0.04999999999998295, Time Penalty: 0.0164778
# Step: 220, Timestamp: 2023-07-03 08:09:23.513596182, Action: 2, Price: 194.05, Shares: 82.0, Reward: -0.18484697612859524, Transaction Cost: 0.09836687612860205, Slippage: 0.06999999999999318, Time Penalty: 0.0164801
# Step: 221, Timestamp: 2023-07-03 08:09:28.098380390, Action: 2, Price: 194.01, Shares: 212.0, Reward: -0.13676211803556518, Transaction Cost: 0.08031621803554471, Slippage: 0.040000000000020464, Time Penalty: 0.0164459
# Step: 222, Timestamp: 2023-07-03 08:09:29.194412216, Action: 2, Price: 194.0, Shares: 131.0, Reward: -0.09756343640860429, Transaction Cost: 0.05079643640860315, Slippage: 0.030000000000001137, Time Penalty: 0.016767
# Step: 227, Timestamp: 2023-07-03 08:09:44.674267162, Action: 1, Price: 194.0, Shares: 209.0, Reward: -0.1862433703093444, Transaction Cost: 0.13911177030934327, Slippage: 0.030000000000001137, Time Penalty: 0.0171316
# Step: 228, Timestamp: 2023-07-03 08:09:44.674267162, Action: 2, Price: 194.0, Shares: 52.0, Reward: -0.30111378204301686, Transaction Cost: 0.25398218204301576, Slippage: 0.030000000000001137, Time Penalty: 0.0171316
# Step: 229, Timestamp: 2023-07-03 08:09:44.674267162, Action: 2, Price: 194.0, Shares: 67.0, Reward: -0.07252981820430271, Transaction Cost: 0.025398218204301576, Slippage: 0.030000000000001137, Time Penalty: 0.0171316
# Step: 230, Timestamp: 2023-07-03 08:09:44.674267162, Action: 2, Price: 194.0, Shares: 90.0, Reward: -0.1125197046446368, Transaction Cost: 0.03591850464463453, Slippage: 0.060000000000002274, Time Penalty: 0.0166012
# Step: 240, Timestamp: 2023-07-03 08:09:58.485383307, Action: 1, Price: 193.98, Shares: 160.0, Reward: -0.0933133424122012, Transaction Cost: 0.056792142412190966, Slippage: 0.020000000000010232, Time Penalty: 0.0165212
# Step: 250, Timestamp: 2023-07-03 08:10:52.104490724, Action: 2, Price: 193.96, Shares: 160.0, Reward: -0.06239080464462543, Transaction Cost: 0.03591850464463453, Slippage: 0.009999999999990905, Time Penalty: 0.0164723
# Step: 251, Timestamp: 2023-07-03 08:10:53.697424519, Action: 1, Price: 193.96, Shares: 224.0, Reward: -0.041859518204301574, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164613
# Step: 253, Timestamp: 2023-07-03 08:11:02.214773646, Action: 1, Price: 193.96, Shares: 82.0, Reward: -0.04184151820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164433
# Step: 254, Timestamp: 2023-07-03 08:11:02.623893885, Action: 2, Price: 193.96, Shares: 142.0, Reward: -0.041865118204301575, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164669
# Step: 258, Timestamp: 2023-07-03 08:11:08.479769664, Action: 2, Price: 193.96, Shares: 164.0, Reward: -0.2679529325124417, Transaction Cost: 0.25142953251244166, Slippage: 0.0, Time Penalty: 0.0165234
# Step: 268, Timestamp: 2023-07-03 08:11:31.974733512, Action: 1, Price: 194.0, Shares: 232.0, Reward: -0.28519517645094183, Transaction Cost: 0.2687894764509418, Slippage: 0.0, Time Penalty: 0.0164057
# Step: 276, Timestamp: 2023-07-03 08:11:36.545404693, Action: 1, Price: 194.05, Shares: 101.0, Reward: -0.04187581820430157, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164776
# Step: 278, Timestamp: 2023-07-03 08:11:43.012969083, Action: 1, Price: 194.06, Shares: 64.0, Reward: -0.10706111803553561, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0167449
# Step: 280, Timestamp: 2023-07-03 08:11:43.012969083, Action: 1, Price: 194.07, Shares: 74.0, Reward: -0.21633742322318286, Transaction Cost: 0.17959252322317262, Slippage: 0.020000000000010232, Time Penalty: 0.0167449
# Step: 282, Timestamp: 2023-07-03 08:11:49.346960376, Action: 2, Price: 194.09, Shares: 76.0, Reward: -0.12434631393390358, Transaction Cost: 0.10775551393390358, Slippage: 0.0, Time Penalty: 0.0165908
# Step: 285, Timestamp: 2023-07-03 08:11:53.827974700, Action: 2, Price: 194.13, Shares: 121.0, Reward: -0.22622682322317378, Transaction Cost: 0.17959252322317262, Slippage: 0.030000000000001137, Time Penalty: 0.0166343
# Step: 289, Timestamp: 2023-07-03 08:12:25.584954214, Action: 2, Price: 194.09, Shares: 165.0, Reward: -0.0620037182043118, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0166055
# Step: 291, Timestamp: 2023-07-03 08:12:25.584954214, Action: 1, Price: 194.09, Shares: 68.0, Reward: -0.08059650435158133, Transaction Cost: 0.04399100435157111, Slippage: 0.020000000000010232, Time Penalty: 0.0166055
# Step: 298, Timestamp: 2023-07-03 08:13:34.271417839, Action: 1, Price: 194.1, Shares: 111.0, Reward: -0.0832448424122103, Transaction Cost: 0.056792142412190966, Slippage: 0.010000000000019327, Time Penalty: 0.0164527
# Step: 303, Timestamp: 2023-07-03 08:13:48.805647196, Action: 2, Price: 194.08, Shares: 186.0, Reward: -0.1415133307550225, Transaction Cost: 0.09503143075502138, Slippage: 0.030000000000001137, Time Penalty: 0.0164819
# Step: 305, Timestamp: 2023-07-03 08:13:54.998093551, Action: 2, Price: 194.05, Shares: 74.0, Reward: -0.32017725100033123, Transaction Cost: 0.24361115100032896, Slippage: 0.060000000000002274, Time Penalty: 0.0165661
# Step: 307, Timestamp: 2023-07-03 08:13:54.998109423, Action: 2, Price: 194.05, Shares: 28.0, Reward: -0.2563220232231749, Transaction Cost: 0.17959252322317262, Slippage: 0.060000000000002274, Time Penalty: 0.0167295
# Step: 309, Timestamp: 2023-07-03 08:14:13.686558750, Action: 1, Price: 194.11, Shares: 122.0, Reward: -0.17709803607108943, Transaction Cost: 0.16063243607108943, Slippage: 0.0, Time Penalty: 0.0164656
# Step: 316, Timestamp: 2023-07-03 08:14:27.759016393, Action: 2, Price: 194.04, Shares: 122.0, Reward: -0.157099118035547, Transaction Cost: 0.08031621803554471, Slippage: 0.060000000000002274, Time Penalty: 0.0167829
# Step: 318, Timestamp: 2023-07-03 08:14:27.759016393, Action: 1, Price: 194.03, Shares: 65.0, Reward: -0.26669442322316583, Transaction Cost: 0.17959252322317262, Slippage: 0.06999999999999318, Time Penalty: 0.0171019
# Step: 319, Timestamp: 2023-07-03 08:14:27.759016393, Action: 2, Price: 194.02, Shares: 65.0, Reward: -0.14712971803552766, Transaction Cost: 0.08031621803554471, Slippage: 0.04999999999998295, Time Penalty: 0.0168135
# Step: 324, Timestamp: 2023-07-03 08:14:45.457003155, Action: 1, Price: 194.02, Shares: 65.0, Reward: -0.14712971803552766, Transaction Cost: 0.08031621803554471, Slippage: 0.04999999999998295, Time Penalty: 0.0168135
# Step: 326, Timestamp: 2023-07-03 08:14:45.457003155, Action: 1, Price: 194.01, Shares: 106.0, Reward: -0.2564060232231749, Transaction Cost: 0.17959252322317262, Slippage: 0.060000000000002274, Time Penalty: 0.0168135
# Step: 328, Timestamp: 2023-07-03 08:14:48.645520202, Action: 2, Price: 194.06, Shares: 171.0, Reward: -0.10870710928925087, Transaction Cost: 0.07183700928926906, Slippage: 0.01999999999998181, Time Penalty: 0.0168701
# Step: 333, Timestamp: 2023-07-03 08:15:02.866333162, Action: 1, Price: 194.04, Shares: 80.0, Reward: -0.12117123635882071, Transaction Cost: 0.10471953635882071, Slippage: 0.0, Time Penalty: 0.0164517
# Step: 336, Timestamp: 2023-07-03 08:15:48.139748433, Action: 2, Price: 194.05, Shares: 80.0, Reward: -0.041834218204301575, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.016436
# Step: 352, Timestamp: 2023-07-03 08:16:27.882453290, Action: 1, Price: 194.01, Shares: 86.0, Reward: -0.10705501803556404, Transaction Cost: 0.08031621803554471, Slippage: 0.010000000000019327, Time Penalty: 0.0167388
# Step: 354, Timestamp: 2023-07-03 08:16:27.882453290, Action: 2, Price: 194.0, Shares: 86.0, Reward: -0.0935309424122012, Transaction Cost: 0.056792142412190966, Slippage: 0.020000000000010232, Time Penalty: 0.0167388
# Step: 359, Timestamp: 2023-07-03 08:16:27.882453290, Action: 1, Price: 194.0, Shares: 213.0, Reward: -0.0626437182043118, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0172455
# Step: 360, Timestamp: 2023-07-03 08:16:27.882453290, Action: 2, Price: 194.0, Shares: 183.0, Reward: -0.0626437182043118, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0172455
# Step: 366, Timestamp: 2023-07-03 08:16:34.421319166, Action: 2, Price: 193.95, Shares: 30.0, Reward: -0.14363834241221257, Transaction Cost: 0.056792142412190966, Slippage: 0.0700000000000216, Time Penalty: 0.0168462
# Step: 369, Timestamp: 2023-07-03 08:16:43.264965245, Action: 1, Price: 193.94, Shares: 245.0, Reward: -0.11244491820429475, Transaction Cost: 0.025398218204301576, Slippage: 0.06999999999999318, Time Penalty: 0.0170467
# Step: 374, Timestamp: 2023-07-03 08:16:43.264965245, Action: 2, Price: 193.91, Shares: 241.0, Reward: -0.29663922322316694, Transaction Cost: 0.17959252322317262, Slippage: 0.09999999999999432, Time Penalty: 0.0170467
# Step: 377, Timestamp: 2023-07-03 08:17:06.716469670, Action: 1, Price: 194.0, Shares: 229.0, Reward: -0.06190541820431181, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0165072
# Step: 378, Timestamp: 2023-07-03 08:17:13.876550409, Action: 1, Price: 194.01, Shares: 139.0, Reward: -0.20611212322319195, Transaction Cost: 0.17959252322317262, Slippage: 0.010000000000019327, Time Penalty: 0.0165196
# Step: 380, Timestamp: 2023-07-03 08:17:20.959388580, Action: 2, Price: 193.9, Shares: 120.0, Reward: -0.09344734241217277, Transaction Cost: 0.056792142412190966, Slippage: 0.01999999999998181, Time Penalty: 0.0166552
# Step: 381, Timestamp: 2023-07-03 08:17:20.959388580, Action: 2, Price: 193.9, Shares: 196.0, Reward: -0.11697141803552652, Transaction Cost: 0.08031621803554471, Slippage: 0.01999999999998181, Time Penalty: 0.0166552
# Step: 382, Timestamp: 2023-07-03 08:17:24.018681802, Action: 1, Price: 193.91, Shares: 69.0, Reward: -0.27043158204301576, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0164494
# Step: 387, Timestamp: 2023-07-03 08:17:24.981863912, Action: 1, Price: 193.9, Shares: 238.0, Reward: -0.052366018204292486, Transaction Cost: 0.025398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0169678
# Step: 389, Timestamp: 2023-07-03 08:17:25.912153251, Action: 2, Price: 193.9, Shares: 91.0, Reward: -0.10684831803553563, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0165321
# Step: 391, Timestamp: 2023-07-03 08:17:29.577495606, Action: 2, Price: 193.89, Shares: 208.0, Reward: -0.06192421820431181, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.016526
# Step: 392, Timestamp: 2023-07-03 08:17:33.863491286, Action: 2, Price: 193.85, Shares: 64.0, Reward: -0.10043970435156316, Transaction Cost: 0.04399100435157111, Slippage: 0.03999999999999204, Time Penalty: 0.0164487
# Step: 393, Timestamp: 2023-07-03 08:17:35.714288710, Action: 1, Price: 193.85, Shares: 52.0, Reward: -0.08183921820429362, Transaction Cost: 0.025398218204301576, Slippage: 0.03999999999999204, Time Penalty: 0.016441
# Step: 395, Timestamp: 2023-07-03 08:17:47.816930682, Action: 1, Price: 193.88, Shares: 164.0, Reward: -0.10680691803553562, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0164907
# Step: 397, Timestamp: 2023-07-03 08:17:54.774687334, Action: 1, Price: 193.9, Shares: 105.0, Reward: -0.10678281803553562, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0164666
# Step: 398, Timestamp: 2023-07-03 08:17:54.959833561, Action: 2, Price: 193.85, Shares: 241.0, Reward: -0.10188461820430385, Transaction Cost: 0.025398218204301576, Slippage: 0.060000000000002274, Time Penalty: 0.0164864
# Step: 399, Timestamp: 2023-07-03 08:18:03.109875226, Action: 2, Price: 193.85, Shares: 80.0, Reward: -0.22803689419728423, Transaction Cost: 0.14141129419729104, Slippage: 0.06999999999999318, Time Penalty: 0.0166256
# Step: 427, Timestamp: 2023-07-03 08:22:02.484047215, Action: 1, Price: 193.82, Shares: 119.0, Reward: -0.13070566012724355, Transaction Cost: 0.08423636012724241, Slippage: 0.030000000000001137, Time Penalty: 0.0164693
# Step: 430, Timestamp: 2023-07-03 08:22:05.585438246, Action: 1, Price: 193.81, Shares: 167.0, Reward: -0.08252741820429361, Transaction Cost: 0.025398218204301576, Slippage: 0.03999999999999204, Time Penalty: 0.0171292
# Step: 431, Timestamp: 2023-07-03 08:22:05.585438246, Action: 2, Price: 193.81, Shares: 242.0, Reward: -0.08252741820429361, Transaction Cost: 0.025398218204301576, Slippage: 0.03999999999999204, Time Penalty: 0.0171292
# Step: 432, Timestamp: 2023-07-03 08:22:05.585438246, Action: 2, Price: 193.81, Shares: 44.0, Reward: -0.08252741820429361, Transaction Cost: 0.025398218204301576, Slippage: 0.03999999999999204, Time Penalty: 0.0171292
# Step: 436, Timestamp: 2023-07-03 08:22:12.711809001, Action: 1, Price: 193.82, Shares: 159.0, Reward: -0.09075430435157225, Transaction Cost: 0.04399100435157111, Slippage: 0.030000000000001137, Time Penalty: 0.0167633
# Step: 437, Timestamp: 2023-07-03 08:22:20.540108824, Action: 2, Price: 193.85, Shares: 139.0, Reward: -0.04184251820430157, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164443
# Step: 439, Timestamp: 2023-07-03 08:22:25.644010327, Action: 2, Price: 193.82, Shares: 20.0, Reward: -0.21563562184876958, Transaction Cost: 0.1586118218487491, Slippage: 0.040000000000020464, Time Penalty: 0.0170238
# Step: 448, Timestamp: 2023-07-03 08:22:30.077803363, Action: 1, Price: 193.77, Shares: 244.0, Reward: -0.10216141820430386, Transaction Cost: 0.025398218204301576, Slippage: 0.060000000000002274, Time Penalty: 0.0167632
# Step: 449, Timestamp: 2023-07-03 08:22:30.077803363, Action: 1, Price: 193.76, Shares: 107.0, Reward: -0.11216141820432318, Transaction Cost: 0.025398218204301576, Slippage: 0.0700000000000216, Time Penalty: 0.0167632
# Step: 457, Timestamp: 2023-07-03 08:22:33.567677034, Action: 2, Price: 193.83, Shares: 248.0, Reward: -0.21665012322315444, Transaction Cost: 0.17959252322317262, Slippage: 0.01999999999998181, Time Penalty: 0.0170576
# Step: 458, Timestamp: 2023-07-03 08:22:33.568657920, Action: 1, Price: 193.83, Shares: 155.0, Reward: -0.4689486708071388, Transaction Cost: 0.432516070807157, Slippage: 0.01999999999998181, Time Penalty: 0.0164326
# Step: 469, Timestamp: 2023-07-03 08:24:45.289544720, Action: 2, Price: 193.78, Shares: 178.0, Reward: -0.11707721803555494, Transaction Cost: 0.08031621803554471, Slippage: 0.020000000000010232, Time Penalty: 0.016761
# Step: 474, Timestamp: 2023-07-03 08:25:30.184408656, Action: 2, Price: 193.79, Shares: 80.0, Reward: -0.12706711803554585, Transaction Cost: 0.08031621803554471, Slippage: 0.030000000000001137, Time Penalty: 0.0167509
# Step: 491, Timestamp: 2023-07-03 08:26:21.060169624, Action: 1, Price: 193.76, Shares: 224.0, Reward: -0.12706711803554585, Transaction Cost: 0.08031621803554471, Slippage: 0.030000000000001137, Time Penalty: 0.0167509
# Step: 494, Timestamp: 2023-07-03 08:26:23.813145405, Action: 2, Price: 193.76, Shares: 65.0, Reward: -0.10387416911274569, Transaction Cost: 0.06719736911273545, Slippage: 0.020000000000010232, Time Penalty: 0.0166768
# Step: 495, Timestamp: 2023-07-03 08:26:44.023325234, Action: 2, Price: 193.78, Shares: 86.0, Reward: -0.04182981820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164316
# Step: 496, Timestamp: 2023-07-03 08:27:04.023548544, Action: 1, Price: 193.78, Shares: 101.0, Reward: -0.08362036911273546, Transaction Cost: 0.06719736911273545, Slippage: 0.0, Time Penalty: 0.016423
# Step: 499, Timestamp: 2023-07-03 08:27:33.718614471, Action: 2, Price: 193.8, Shares: 174.0, Reward: -0.3211685820430271, Transaction Cost: 0.25398218204301576, Slippage: 0.05000000000001137, Time Penalty: 0.0171864
# Step: 514, Timestamp: 2023-07-03 08:28:41.168657744, Action: 1, Price: 193.73, Shares: 222.0, Reward: -0.09258461820431295, Transaction Cost: 0.025398218204301576, Slippage: 0.05000000000001137, Time Penalty: 0.0171864
# Step: 517, Timestamp: 2023-07-03 08:29:25.851498092, Action: 1, Price: 193.75, Shares: 65.0, Reward: -0.1032314424121921, Transaction Cost: 0.056792142412190966, Slippage: 0.030000000000001137, Time Penalty: 0.0164393
# Step: 523, Timestamp: 2023-07-03 08:29:42.783672090, Action: 2, Price: 193.72, Shares: 108.0, Reward: -0.10230321820430385, Transaction Cost: 0.025398218204301576, Slippage: 0.060000000000002274, Time Penalty: 0.016905
# Step: 524, Timestamp: 2023-07-03 08:29:42.783672090, Action: 2, Price: 193.72, Shares: 113.0, Reward: -0.10230321820430385, Transaction Cost: 0.025398218204301576, Slippage: 0.060000000000002274, Time Penalty: 0.016905
# Step: 526, Timestamp: 2023-07-03 08:30:28.434147054, Action: 2, Price: 193.79, Shares: 64.0, Reward: -0.05246680464463453, Transaction Cost: 0.03591850464463453, Slippage: 0.0, Time Penalty: 0.0165483
# Step: 528, Timestamp: 2023-07-03 08:30:32.158881684, Action: 2, Price: 193.76, Shares: 2.0, Reward: -0.1448168761286032, Transaction Cost: 0.09836687612860205, Slippage: 0.030000000000001137, Time Penalty: 0.01645
# Step: 537, Timestamp: 2023-07-03 08:31:48.417944485, Action: 1, Price: 193.78, Shares: 147.0, Reward: -0.05193821820429248, Transaction Cost: 0.025398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.01654
# Step: 538, Timestamp: 2023-07-03 08:31:48.417944485, Action: 2, Price: 193.77, Shares: 147.0, Reward: -0.06743993640860316, Transaction Cost: 0.05079643640860315, Slippage: 0.0, Time Penalty: 0.0166435
# Step: 553, Timestamp: 2023-07-03 08:33:22.409432404, Action: 1, Price: 193.82, Shares: 159.0, Reward: -0.09720393640860428, Transaction Cost: 0.05079643640860315, Slippage: 0.030000000000001137, Time Penalty: 0.0164075
# Step: 556, Timestamp: 2023-07-03 08:33:23.564095886, Action: 2, Price: 193.85, Shares: 136.0, Reward: -0.09722951803554472, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0169133
# Step: 563, Timestamp: 2023-07-03 08:34:15.866892264, Action: 2, Price: 193.84, Shares: 23.0, Reward: -0.19944324657155346, Transaction Cost: 0.16262794657157165, Slippage: 0.01999999999998181, Time Penalty: 0.0168153
# Step: 582, Timestamp: 2023-07-03 08:36:03.305264849, Action: 1, Price: 193.83, Shares: 145.0, Reward: -0.26278526160651494, Transaction Cost: 0.24624486160651493, Slippage: 0.0, Time Penalty: 0.0165404
# Step: 587, Timestamp: 2023-07-03 08:36:17.308154337, Action: 2, Price: 193.82, Shares: 85.0, Reward: -0.19497932025450415, Transaction Cost: 0.16847272025448481, Slippage: 0.010000000000019327, Time Penalty: 0.0165066
# ...
# Step: 57492, Timestamp: 2023-07-03 16:59:21.329541835, Action: 2, Price: 192.51, Shares: 16.0, Reward: -0.231757181510627, Transaction Cost: 0.20476698151060765, Slippage: 0.010000000000019327, Time Penalty: 0.0169902
# Step: 57513, Timestamp: 2023-07-03 16:59:22.008241692, Action: 2, Price: 192.5, Shares: 17.0, Reward: -0.2817837820430067, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0178016
# Step: 57514, Timestamp: 2023-07-03 16:59:22.008241692, Action: 2, Price: 192.5, Shares: 10.0, Reward: -0.06372010464462544, Transaction Cost: 0.03591850464463453, Slippage: 0.009999999999990905, Time Penalty: 0.0178016
# Step: 57522, Timestamp: 2023-07-03 16:59:22.008523451, Action: 2, Price: 192.5, Shares: 14.0, Reward: -0.16175663822546182, Transaction Cost: 0.1343947382254709, Slippage: 0.009999999999990905, Time Penalty: 0.0173619
# Step: 57552, Timestamp: 2023-07-03 16:59:23.855190197, Action: 2, Price: 192.49, Shares: 12.0, Reward: -0.28083078204300665, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0168486
# Step: 57597, Timestamp: 2023-07-03 16:59:25.645173969, Action: 1, Price: 192.5, Shares: 21.0, Reward: -0.3406949430593754, Transaction Cost: 0.3242627430593754, Slippage: 0.0, Time Penalty: 0.0164322
# Step: 57669, Timestamp: 2023-07-03 16:59:29.808785409, Action: 1, Price: 192.48, Shares: 15.0, Reward: -0.2716076820430158, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0176255
# Step: 57707, Timestamp: 2023-07-03 16:59:31.728682314, Action: 2, Price: 192.48, Shares: 10.0, Reward: -0.09380156911275478, Transaction Cost: 0.06719736911273545, Slippage: 0.010000000000019327, Time Penalty: 0.0166042
# Step: 57725, Timestamp: 2023-07-03 16:59:33.418684508, Action: 1, Price: 192.49, Shares: 7.0, Reward: -0.27048088204301574, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0164987
# Step: 57731, Timestamp: 2023-07-03 16:59:33.512498213, Action: 2, Price: 192.49, Shares: 4.0, Reward: -0.09404585461290473, Transaction Cost: 0.07619465461290473, Slippage: 0.0, Time Penalty: 0.0178512
# Step: 57732, Timestamp: 2023-07-03 16:59:33.512498213, Action: 2, Price: 192.49, Shares: 13.0, Reward: -0.1448422910215079, Transaction Cost: 0.12699109102150788, Slippage: 0.0, Time Penalty: 0.0178512
# Step: 57772, Timestamp: 2023-07-03 16:59:35.137249298, Action: 2, Price: 192.5, Shares: 16.0, Reward: -0.20891554239335647, Transaction Cost: 0.19175234239335648, Slippage: 0.0, Time Penalty: 0.0171632
# Step: 57776, Timestamp: 2023-07-03 16:59:35.137249298, Action: 1, Price: 192.5, Shares: 9.0, Reward: -0.27114538204301575, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0171632
# Step: 57785, Timestamp: 2023-07-03 16:59:35.140723856, Action: 1, Price: 192.51, Shares: 12.0, Reward: -0.23657273419672548, Transaction Cost: 0.21848373419672548, Slippage: 0.0, Time Penalty: 0.018089
# Step: 57797, Timestamp: 2023-07-03 16:59:35.141514422, Action: 1, Price: 192.51, Shares: 19.0, Reward: -0.38561494644636457, Transaction Cost: 0.35918504644634525, Slippage: 0.010000000000019327, Time Penalty: 0.0164299
# Step: 57827, Timestamp: 2023-07-03 16:59:35.873835324, Action: 2, Price: 192.52, Shares: 5.0, Reward: -0.28077638204300664, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0167942
# Step: 57838, Timestamp: 2023-07-03 16:59:37.030504722, Action: 2, Price: 192.52, Shares: 18.0, Reward: -0.3315981156972137, Transaction Cost: 0.3037185156972228, Slippage: 0.009999999999990905, Time Penalty: 0.0178796
# Step: 57841, Timestamp: 2023-07-03 16:59:37.030504722, Action: 1, Price: 192.52, Shares: 9.0, Reward: -0.6998532911273454, Transaction Cost: 0.6719736911273545, Slippage: 0.009999999999990905, Time Penalty: 0.0178796
# Step: 57885, Timestamp: 2023-07-03 16:59:38.085005210, Action: 1, Price: 192.53, Shares: 6.0, Reward: -0.27140778204301574, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0174256
# Step: 57914, Timestamp: 2023-07-03 16:59:39.063941202, Action: 1, Price: 192.52, Shares: 21.0, Reward: -0.28078218204300665, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0168
# Step: 57934, Timestamp: 2023-07-03 16:59:39.856192670, Action: 2, Price: 192.53, Shares: 10.0, Reward: -0.4236549510909707, Transaction Cost: 0.3951035510909798, Slippage: 0.009999999999990905, Time Penalty: 0.0185514
# Step: 57943, Timestamp: 2023-07-03 16:59:40.019850462, Action: 2, Price: 192.52, Shares: 15.0, Reward: -0.27069748204301575, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0167153
# Step: 58001, Timestamp: 2023-07-03 16:59:41.760509208, Action: 2, Price: 192.52, Shares: 13.0, Reward: -0.20984475608205544, Transaction Cost: 0.18314915608206453, Slippage: 0.009999999999990905, Time Penalty: 0.0166956
# Step: 58010, Timestamp: 2023-07-03 16:59:42.025276732, Action: 2, Price: 192.51, Shares: 20.0, Reward: -0.2818389820430351, Transaction Cost: 0.25398218204301576, Slippage: 0.010000000000019327, Time Penalty: 0.0178568
# Step: 58021, Timestamp: 2023-07-03 16:59:42.124503946, Action: 1, Price: 192.51, Shares: 20.0, Reward: -0.33795626305136667, Transaction Cost: 0.31002476305134735, Slippage: 0.010000000000019327, Time Penalty: 0.0179315
# Step: 58043, Timestamp: 2023-07-03 16:59:43.252868303, Action: 1, Price: 192.51, Shares: 11.0, Reward: -0.2759351999056421, Transaction Cost: 0.24885069990562278, Slippage: 0.010000000000019327, Time Penalty: 0.0170845
# Step: 58074, Timestamp: 2023-07-03 16:59:44.060746022, Action: 2, Price: 192.51, Shares: 12.0, Reward: -0.1539461910215272, Transaction Cost: 0.12699109102150788, Slippage: 0.010000000000019327, Time Penalty: 0.0169551
# Step: 58077, Timestamp: 2023-07-03 16:59:44.097611272, Action: 2, Price: 192.515, Shares: 19.0, Reward: -0.1780638319490821, Transaction Cost: 0.15656513194905822, Slippage: 0.005000000000023874, Time Penalty: 0.0164987
# Step: 58080, Timestamp: 2023-07-03 16:59:44.534689441, Action: 1, Price: 192.51, Shares: 22.0, Reward: -0.20253881740630378, Transaction Cost: 0.17596401740628445, Slippage: 0.010000000000019327, Time Penalty: 0.0165748
# Step: 58088, Timestamp: 2023-07-03 16:59:44.756499372, Action: 2, Price: 192.53, Shares: 6.0, Reward: -0.27117088204301576, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0171887
# Step: 58110, Timestamp: 2023-07-03 16:59:45.017504752, Action: 1, Price: 192.52, Shares: 7.0, Reward: -0.27219168204301575, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0182095
# Step: 58112, Timestamp: 2023-07-03 16:59:45.019457668, Action: 2, Price: 192.52, Shares: 15.0, Reward: -0.09391026911272636, Transaction Cost: 0.06719736911273545, Slippage: 0.009999999999990905, Time Penalty: 0.0167129
# Step: 58143, Timestamp: 2023-07-03 16:59:45.475369804, Action: 1, Price: 192.51, Shares: 5.0, Reward: -0.1215400307550407, Transaction Cost: 0.09503143075502138, Slippage: 0.010000000000019327, Time Penalty: 0.0165086
# Step: 58178, Timestamp: 2023-07-03 16:59:46.711961849, Action: 1, Price: 192.5, Shares: 6.0, Reward: -0.28463578204300666, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0206536
# Step: 58188, Timestamp: 2023-07-03 16:59:46.712054653, Action: 1, Price: 192.5, Shares: 17.0, Reward: -0.05452401820429248, Transaction Cost: 0.025398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0191258
# Step: 58257, Timestamp: 2023-07-03 16:59:48.000426696, Action: 1, Price: 192.495, Shares: 16.0, Reward: -0.0727431364085986, Transaction Cost: 0.05079643640860315, Slippage: 0.0049999999999954525, Time Penalty: 0.0169467
# Step: 58271, Timestamp: 2023-07-03 16:59:48.014884290, Action: 1, Price: 192.5, Shares: 12.0, Reward: -0.27127728204301577, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0172951
# Step: 58272, Timestamp: 2023-07-03 16:59:48.014884290, Action: 1, Price: 192.5, Shares: 11.0, Reward: -0.20688762322316354, Transaction Cost: 0.17959252322317262, Slippage: 0.009999999999990905, Time Penalty: 0.0172951
# Step: 58284, Timestamp: 2023-07-03 16:59:48.033372230, Action: 2, Price: 192.48, Shares: 21.0, Reward: -0.11776551803555495, Transaction Cost: 0.08031621803554471, Slippage: 0.020000000000010232, Time Penalty: 0.0174493
# Step: 58288, Timestamp: 2023-07-03 16:59:48.034455040, Action: 2, Price: 192.49, Shares: 21.0, Reward: -0.27097748204301575, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0169953
# Step: 58306, Timestamp: 2023-07-03 16:59:48.687031035, Action: 1, Price: 192.485, Shares: 16.0, Reward: -0.3809360464463407, Transaction Cost: 0.35918504644634525, Slippage: 0.0049999999999954525, Time Penalty: 0.016751
# Step: 58315, Timestamp: 2023-07-03 16:59:48.705093649, Action: 1, Price: 192.5, Shares: 13.0, Reward: -0.27045668204301576, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0164745
# Step: 58418, Timestamp: 2023-07-03 16:59:50.076719547, Action: 2, Price: 192.47, Shares: 14.0, Reward: -0.27119308204301573, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0172109
# Step: 58424, Timestamp: 2023-07-03 16:59:50.106959664, Action: 1, Price: 192.47, Shares: 20.0, Reward: -0.27105998204301573, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0170778
# Step: 58446, Timestamp: 2023-07-03 16:59:50.307049676, Action: 1, Price: 192.47, Shares: 16.0, Reward: -0.05247930464463453, Transaction Cost: 0.03591850464463453, Slippage: 0.0, Time Penalty: 0.0165608
# Step: 58447, Timestamp: 2023-07-03 16:59:50.410909142, Action: 1, Price: 192.46, Shares: 13.0, Reward: -0.0890013749763966, Transaction Cost: 0.062212674976405695, Slippage: 0.009999999999990905, Time Penalty: 0.0167887
# Step: 58456, Timestamp: 2023-07-03 16:59:50.802354566, Action: 1, Price: 192.46, Shares: 8.0, Reward: -0.09927867497638751, Transaction Cost: 0.062212674976405695, Slippage: 0.01999999999998181, Time Penalty: 0.017066
# Step: 58466, Timestamp: 2023-07-03 16:59:51.232613895, Action: 1, Price: 192.47, Shares: 5.0, Reward: -0.11822397804102316, Transaction Cost: 0.09157457804103226, Slippage: 0.009999999999990905, Time Penalty: 0.0166494
# Step: 58474, Timestamp: 2023-07-03 16:59:51.461835113, Action: 2, Price: 192.48, Shares: 18.0, Reward: -0.27104848204301574, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0170663
# Step: 58543, Timestamp: 2023-07-03 16:59:54.439559777, Action: 1, Price: 192.49, Shares: 16.0, Reward: -0.08082920435155291, Transaction Cost: 0.04399100435157111, Slippage: 0.01999999999998181, Time Penalty: 0.0168382
# Step: 58558, Timestamp: 2023-07-03 16:59:55.825704122, Action: 1, Price: 192.495, Shares: 17.0, Reward: -0.04691511820429703, Transaction Cost: 0.025398218204301576, Slippage: 0.0049999999999954525, Time Penalty: 0.0165169
# Step: 58568, Timestamp: 2023-07-03 16:59:56.278787743, Action: 2, Price: 192.49, Shares: 17.0, Reward: -0.2812528820430067, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0172707
# Step: 58569, Timestamp: 2023-07-03 16:59:56.278787743, Action: 2, Price: 192.49, Shares: 8.0, Reward: -0.2812528820430067, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0172707
# Step: 58617, Timestamp: 2023-07-03 16:59:57.989578323, Action: 1, Price: 192.47, Shares: 20.0, Reward: -0.2012042663836709, Transaction Cost: 0.16459926638366065, Slippage: 0.020000000000010232, Time Penalty: 0.016605
# Step: 58632, Timestamp: 2023-07-03 16:59:58.025059195, Action: 1, Price: 192.46, Shares: 4.0, Reward: -0.3295961997642121, Transaction Cost: 0.3026546997642212, Slippage: 0.009999999999990905, Time Penalty: 0.0169415
# Step: 58645, Timestamp: 2023-07-03 16:59:58.201230277, Action: 2, Price: 192.46, Shares: 6.0, Reward: -0.3186819313591108, Transaction Cost: 0.3015871313591108, Slippage: 0.0, Time Penalty: 0.0170948
# Step: 58649, Timestamp: 2023-07-03 16:59:58.400761266, Action: 1, Price: 192.47, Shares: 9.0, Reward: -0.7783985461290474, Transaction Cost: 0.7619465461290473, Slippage: 0.0, Time Penalty: 0.016452
# Step: 58660, Timestamp: 2023-07-03 16:59:58.799779511, Action: 1, Price: 192.47, Shares: 17.0, Reward: -0.6883996911273546, Transaction Cost: 0.6719736911273545, Slippage: 0.0, Time Penalty: 0.016426
# Step: 58671, Timestamp: 2023-07-03 16:59:59.542319812, Action: 1, Price: 192.465, Shares: 13.0, Reward: -0.3508476327673168, Transaction Cost: 0.3291985327673213, Slippage: 0.0049999999999954525, Time Penalty: 0.0166491
# Step: 58675, Timestamp: 2023-07-03 16:59:59.899025246, Action: 1, Price: 192.465, Shares: 10.0, Reward: -0.3808007464463407, Transaction Cost: 0.35918504644634525, Slippage: 0.0049999999999954525, Time Penalty: 0.0166157
# Step: 58686, Timestamp: 2023-07-03 17:00:00.377728478, Action: 2, Price: 192.46, Shares: 15.0, Reward: -0.21713682322315442, Transaction Cost: 0.17959252322317262, Slippage: 0.01999999999998181, Time Penalty: 0.0175443
# Step: 58697, Timestamp: 2023-07-03 17:00:37.471722007, Action: 1, Price: 192.35, Shares: 14.0, Reward: -0.12186971820431408, Transaction Cost: 0.025398218204301576, Slippage: 0.0800000000000125, Time Penalty: 0.0164715
# Step: 58865, Timestamp: 2023-07-03 17:16:07.733953097, Action: 1, Price: 192.43, Shares: 16.0, Reward: -0.28060438204300664, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0166222
# Step: 58897, Timestamp: 2023-07-03 17:29:03.198883050, Action: 1, Price: 192.4, Shares: 14.0, Reward: -0.08364816911273545, Transaction Cost: 0.06719736911273545, Slippage: 0.0, Time Penalty: 0.0164508
# Step: 58909, Timestamp: 2023-07-03 17:40:46.531814197, Action: 1, Price: 192.38, Shares: 9.0, Reward: -0.09265365461290473, Transaction Cost: 0.07619465461290473, Slippage: 0.0, Time Penalty: 0.016459
# Step: 58957, Timestamp: 2023-07-03 18:11:58.923237451, Action: 2, Price: 192.41, Shares: 8.0, Reward: -0.5243813640860315, Transaction Cost: 0.5079643640860315, Slippage: 0.0, Time Penalty: 0.016417
# Step: 58979, Timestamp: 2023-07-03 18:28:45.693217583, Action: 1, Price: 192.46, Shares: 19.0, Reward: -0.20924284657157277, Transaction Cost: 0.16262794657157165, Slippage: 0.030000000000001137, Time Penalty: 0.0166149
# Step: 59013, Timestamp: 2023-07-03 18:46:38.657590585, Action: 1, Price: 192.45, Shares: 12.0, Reward: -0.041846318204301576, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164481
# Step: 59021, Timestamp: 2023-07-03 18:48:19.772706650, Action: 1, Price: 192.46, Shares: 17.0, Reward: -0.1007737601272424, Transaction Cost: 0.08423636012724241, Slippage: 0.0, Time Penalty: 0.0165374
# Step: 59045, Timestamp: 2023-07-03 19:09:29.231863713, Action: 1, Price: 192.39, Shares: 5.0, Reward: -0.23262155558507458, Transaction Cost: 0.145901655585053, Slippage: 0.0700000000000216, Time Penalty: 0.0167199
# Step: 59050, Timestamp: 2023-07-03 19:12:18.872185729, Action: 1, Price: 192.45, Shares: 6.0, Reward: -0.0518651182043209, Transaction Cost: 0.025398218204301576, Slippage: 0.010000000000019327, Time Penalty: 0.0164669
# Step: 59065, Timestamp: 2023-07-03 19:16:38.947045644, Action: 1, Price: 192.36, Shares: 12.0, Reward: -0.16889840922580945, Transaction Cost: 0.15238930922580946, Slippage: 0.0, Time Penalty: 0.0165091
# Step: 59198, Timestamp: 2023-07-03 20:21:46.163018563, Action: 1, Price: 192.4, Shares: 10.0, Reward: -0.04189701820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164988
# Step: 59229, Timestamp: 2023-07-03 20:58:28.287185646, Action: 2, Price: 192.4, Shares: 19.0, Reward: -0.0718444182043027, Transaction Cost: 0.025398218204301576, Slippage: 0.030000000000001137, Time Penalty: 0.0164462
# Step: 59234, Timestamp: 2023-07-03 20:59:56.889614660, Action: 1, Price: 192.45, Shares: 10.0, Reward: -0.06046120435157111, Transaction Cost: 0.04399100435157111, Slippage: 0.0, Time Penalty: 0.0164702

# %% [markdown]
# ### TRADING BLOTTER:

# %% [markdown]
# #### Preprocess the data for the trading blotter:

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

INITIAL_CASH = 10_000_000  # $10 million


def preprocess_data(df):
    df['liquidity'] = df['bid_sz_00'] * df['bid_px_00'] + df['ask_sz_00'] * df['ask_px_00']
    return df

def calculate_rsi(data, window=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_vol_and_liquidity(price_df, volume_df, window_size):
    # Calculate rolling statistics
    rolling_mean_vol = price_df.pct_change().rolling(window=window_size).mean()
    rolling_std_vol = price_df.pct_change().rolling(window=window_size).std()
    rolling_mean_liq = volume_df.rolling(window=window_size).mean()
    rolling_std_liq = volume_df.rolling(window=window_size).std()
    
    return rolling_mean_vol, rolling_std_vol, rolling_mean_liq, rolling_std_liq

def get_percentile(current_value, mean, std):
    if std > 0:
        z_score = (current_value - mean) / std
        percentile = norm.cdf(z_score)
    else:
        percentile = 0.5  # No variation
    return percentile

def get_trade_price(base_price, current_vol, current_liq, mean_vol, std_vol, mean_liq, std_liq, trade_direction):
    vol_percentile = get_percentile(current_vol, mean_vol, std_vol)
    liq_percentile = get_percentile(current_liq, mean_liq, std_liq)

    # Define price adjustment scenarios based on market conditions
    if vol_percentile >= 0.9 and liq_percentile < 0.1:
        price_adjustment_percent = np.random.uniform(-0.25, -0.15)
    elif vol_percentile <= 0.1 and liq_percentile < 0.1:
        price_adjustment_percent = np.random.uniform(-0.10, -0.05)
    elif vol_percentile >= 0.9 and liq_percentile >= 0.9:
        price_adjustment_percent = np.random.uniform(-0.05, +0.10)
    else:
        price_adjustment_percent = np.random.uniform(-0.05, +0.05)  # Default for normal conditions

    # Adjust price based on trade direction
    if trade_direction == 'BUY':
        adjusted_price = base_price * (1 - price_adjustment_percent)
    else:  # SELL
        adjusted_price = base_price * (1 + price_adjustment_percent)
    
    return adjusted_price

# %% [markdown]
# #### Create trading environment for the blotter

# %%
# Additional condition based on new features
class TradingEnvironmentwithBlotter:
    def __init__(self, data, daily_trading_limit, window_size):
        self.data = preprocess_data(data)
        self.daily_trading_limit = daily_trading_limit
        self.window_size = window_size
        self.state_columns = ['Close', 'Volume', 'RSI', 'MACD', 'MACD_signal', 'MACD_hist', 'Stoch_k', 'Stoch_d',
                              'OBV', 'Upper_BB', 'Middle_BB', 'Lower_BB', 'ATR_1', 'ADX', '+DI', '-DI', 'CCI',
                             'smoothed_ofi', 'Liquidity_Shock', 'VWAP_Deviation', 'Volume_Spike', 'Institutional_Activity_Ratio']

        self.reset()

    def reset(self):
        self.current_step = 0
        self.balance = INITIAL_CASH
        self.shares_held = 0
        self.total_shares_traded = 0
        self.cumulative_reward = 0
        self.trades = []
        self.portfolio = {'cash': self.balance, 'holdings': {ticker: 0 for ticker in self.data['symbol'].unique()}}
        self.data['RSI'] = calculate_rsi(self.data['price'])
        
        self.data['pct_change'] = self.data['price'].pct_change()
        self.data['rolling_mean_vol'], self.data['rolling_std_vol'], self.data['rolling_mean_liq'], self.data['rolling_std_liq'] = calculate_vol_and_liquidity(self.data['price'], self.data['liquidity'], self.window_size)

    def step(self):
        row = self.data.iloc[self.current_step]
        current_price = row['price']
        current_time = pd.to_datetime(row['ts_event'])
        current_rsi = row['RSI']
        # add 5 new features below
        current_smoothed_ofi = row['smoothed_ofi']
        current_liquidity_shock = row['Liquidity_Shock']
        current_vwap_deviation = row['VWAP_Deviation']
        current_volume_spike = row['Volume_Spike']
        current_institutional_activity_ratio = row['Institutional_Activity_Ratio']
        # original
        current_vol = row['pct_change']
        current_liq = row['liquidity']
        mean_vol = row['rolling_mean_vol']
        std_vol = row['rolling_std_vol']
        mean_liq = row['rolling_mean_liq']
        std_liq = row['rolling_std_liq']

        if current_rsi < 30 and current_liquidity_shock > 0 and current_institutional_activity_ratio > 0.5:  # Entry signals
            trade_direction = 'BUY'
            trade_price = get_trade_price(current_price, current_vol, current_liq, mean_vol, std_vol, mean_liq, std_liq, trade_direction)
            trade_size = (self.portfolio['cash'] * np.random.uniform(0.001, 0.005)) / trade_price
            if self.portfolio['cash'] >= trade_size * trade_price:
                self.portfolio['cash'] -= trade_size * trade_price
                self.portfolio['holdings'][row['symbol']] += trade_size
                trade_status = 'filled'
            else:
                trade_status = 'cancelled'
        elif current_rsi > 70 and current_vwap_deviation < 0 and current_institutional_activity_ratio < 0.5:  # Exit signals
            trade_direction = 'SELL'
            if self.portfolio['holdings'][row['symbol']] > 0:
                trade_size = min(self.portfolio['holdings'][row['symbol']], self.portfolio['cash']*np.random.uniform(0.001, 0.005) / current_price)
                trade_price = get_trade_price(current_price, current_vol, current_liq, mean_vol, std_vol, mean_liq, std_liq, trade_direction)
                self.portfolio['cash'] += trade_size * trade_price
                self.portfolio['holdings'][row['symbol']] -= trade_size
                trade_status = 'filled'
            else:
                trade_size = 0
                trade_status = 'cancelled'
        else:
            trade_direction = 'HOLD'
            trade_size = 0
            trade_price = current_price
            trade_status = 'skipped'

        if trade_size > 0:
            expected_price = row['ask_px_00']
            actual_price = row['price']
            transaction_time = row['ts_in_delta']
            transaction_cost = self._calculate_transaction_cost(row['Volume'], 0.3, self.data['Volume'].mean())
            slippage = expected_price - actual_price
            time_penalty = 1000 * transaction_time / 1e9
            reward = - (slippage + time_penalty + transaction_cost)
        
            self.cumulative_reward += reward
            self.trades.append({
                'step': self.current_step,
                'timestamp': current_time,
                'action': trade_direction,
                'price': trade_price,
                'shares': trade_size,
                'symbol': row['symbol'],
                'reward': reward,
                'transaction_cost': transaction_cost,
                'slippage': slippage,
                'time_penalty': time_penalty
            })

            

        self.current_step += 1
        if self.current_step >= len(self.data) - 1:
            done=True
            self.current_step = 0

    def _calculate_transaction_cost(self, volume, volatility, daily_volume):
        return volatility * np.sqrt(volume / daily_volume)

    def run(self):
        self.reset()
        for _ in range(len(self.data)):
            self.step()
        return self.cumulative_reward, self.trades

    def render(self):
        print(f'Cumulative reward: {self.cumulative_reward}')
        row = self.data.iloc[self.current_step]
        print(f'Total portfolio value: {self.portfolio["cash"] + self.portfolio["holdings"][row["symbol"]]*row["Close"]}')
        # get trades in a pandas dataframe
        trades_df = pd.DataFrame(self.trades)
        # Save a csv
        trades_df.to_csv('trades_blotter.csv', index=False)
        for trade in self.trades:
            print(f"Step: {trade['step']}, Timestamp: {trade['timestamp']}, Action: {trade['action']}, Price: {trade['price']}, Shares: {trade['shares']}, Symbol: {trade['symbol']}, Reward: {trade['reward']}, Transaction Cost: {trade['transaction_cost']}, Slippage: {trade['slippage']}, Time Penalty: {trade['time_penalty']}")

# %% [markdown]
# #### Run the trading blotter

# %%
# Filter data for the specified ticker
ticker = 'AAPL'  # Specify the ticker you want to trade
ticker_data = market_features_df[market_features_df['symbol'] == ticker]

window_size = 60
daily_trading_limit = 1000
# Create the trading environment
env = TradingEnvironmentwithBlotter(ticker_data, daily_trading_limit=1000, window_size=window_size)  # Daily trading limit of 1000 shares

# Run the environment
cumulative_reward, trades = env.run()

# Render the results
env.render()
# Out:
# Cumulative reward: -8.552255747560551
# Total portfolio value: 10000656.750150425
# Step: 7315, Timestamp: 2023-07-03 13:33:21.307071788, Action: BUY, Price: 188.59383489076805, Shares: 200.86240997891906, Symbol: AAPL, Reward: -0.23457814241221028, Transaction Cost: 0.056792142412190966, Slippage: 0.010000000000019327, Time Penalty: 0.167786
# Step: 7387, Timestamp: 2023-07-03 13:33:26.636868821, Action: SELL, Price: 188.2016553807728, Shares: 94.28976560703893, Symbol: AAPL, Reward: -0.3369949465715626, Transaction Cost: 0.16262794657157165, Slippage: 0.009999999999990905, Time Penalty: 0.164367
# Step: 7388, Timestamp: 2023-07-03 13:33:26.737480332, Action: SELL, Price: 183.91571833636553, Shares: 72.33090903413695, Symbol: AAPL, Reward: -0.25500421803553563, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.164688
# Step: 7389, Timestamp: 2023-07-03 13:33:26.888319161, Action: SELL, Price: 195.7318205936694, Shares: 34.24173533774318, Symbol: AAPL, Reward: -0.2547372180355356, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.164421
# Step: 18463, Timestamp: 2023-07-03 13:57:51.013390272, Action: BUY, Price: 194.05786669555988, Shares: 170.86003614887264, Symbol: AAPL, Reward: -0.530938980035116, Transaction Cost: 0.3564809800351251, Slippage: 0.009999999999990905, Time Penalty: 0.164458
# Step: 18467, Timestamp: 2023-07-03 13:57:51.014709772, Action: BUY, Price: 198.48493934019254, Shares: 104.9394693006699, Symbol: AAPL, Reward: -0.4287241820430351, Transaction Cost: 0.25398218204301576, Slippage: 0.010000000000019327, Time Penalty: 0.164742
# Step: 18482, Timestamp: 2023-07-03 13:57:55.452569964, Action: SELL, Price: 196.78185217971298, Shares: 233.8121327022168, Symbol: AAPL, Reward: -0.41841918204301576, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.164437
# Step: 18483, Timestamp: 2023-07-03 13:57:55.452579885, Action: SELL, Price: 189.71603683304923, Shares: 41.987372747325765, Symbol: AAPL, Reward: -0.4287061820430067, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.164724
# Step: 25815, Timestamp: 2023-07-03 14:23:54.838231582, Action: BUY, Price: 189.9895854414497, Shares: 98.29762883640429, Symbol: AAPL, Reward: -0.5349480464463361, Transaction Cost: 0.35918504644634525, Slippage: 0.009999999999990905, Time Penalty: 0.165763
# Step: 25817, Timestamp: 2023-07-03 14:23:54.850495682, Action: BUY, Price: 188.15232378449682, Shares: 118.05599713195902, Symbol: AAPL, Reward: -0.42889018204300666, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.164908
# Step: 25861, Timestamp: 2023-07-03 14:24:02.112565181, Action: SELL, Price: 186.59371868270728, Shares: 199.40374583828788, Symbol: AAPL, Reward: -0.41893218204301574, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.16495
# Step: 25862, Timestamp: 2023-07-03 14:24:03.462656956, Action: SELL, Price: 185.05986662469886, Shares: 16.949880130075428, Symbol: AAPL, Reward: -0.5086867274796665, Transaction Cost: 0.34358072747966645, Slippage: 0.0, Time Penalty: 0.165106
# Step: 54846, Timestamp: 2023-07-03 16:54:40.666512289, Action: BUY, Price: 191.12629827203457, Shares: 229.66517089658865, Symbol: AAPL, Reward: -0.4925863129013821, Transaction Cost: 0.3282173129013821, Slippage: 0.0, Time Penalty: 0.164369
# Step: 54847, Timestamp: 2023-07-03 16:54:41.369747809, Action: BUY, Price: 190.88404376067302, Shares: 237.68735960253346, Symbol: AAPL, Reward: -0.42593466087157206, Transaction Cost: 0.261490660871572, Slippage: 0.0, Time Penalty: 0.164444
# Step: 54851, Timestamp: 2023-07-03 16:54:42.903914486, Action: SELL, Price: 193.23771145814075, Shares: 180.10139627842244, Symbol: AAPL, Reward: -0.2765778728172063, Transaction Cost: 0.1015928728172063, Slippage: 0.0, Time Penalty: 0.174985
# Step: 54852, Timestamp: 2023-07-03 16:54:45.758796225, Action: SELL, Price: 193.92967673930187, Shares: 233.7424108586273, Symbol: AAPL, Reward: -0.38845607271763233, Transaction Cost: 0.20943907271764142, Slippage: 0.009999999999990905, Time Penalty: 0.169017
# Step: 54853, Timestamp: 2023-07-03 16:54:45.758796225, Action: SELL, Price: 188.39947208440717, Shares: 53.508723362072374, Symbol: AAPL, Reward: -0.6869813640860224, Transaction Cost: 0.5079643640860315, Slippage: 0.009999999999990905, Time Penalty: 0.169017
# Step: 57127, Timestamp: 2023-07-03 16:59:00.118296821, Action: BUY, Price: 192.85313687084124, Shares: 81.74124336599644, Symbol: AAPL, Reward: -0.5341260464463362, Transaction Cost: 0.35918504644634525, Slippage: 0.009999999999990905, Time Penalty: 0.164941
# Step: 57186, Timestamp: 2023-07-03 16:59:01.062095636, Action: SELL, Price: 202.05867877862997, Shares: 60.467471315937715, Symbol: AAPL, Reward: -0.4339151820430112, Transaction Cost: 0.25398218204301576, Slippage: 0.0049999999999954525, Time Penalty: 0.174933
# Step: 57187, Timestamp: 2023-07-03 16:59:01.062095636, Action: SELL, Price: 185.2203693124357, Shares: 21.273772050058724, Symbol: AAPL, Reward: -0.5341180464463453, Transaction Cost: 0.35918504644634525, Slippage: 0.0, Time Penalty: 0.174933

# %%
df=market_features_df.copy()

# %%
df['timestamp']=pd.to_datetime(df['ts_recv'])

# %%
df.head()
# Out:
#                 ts_recv             ts_event  rtype  publisher_id  \
# 35  1688371214386057385  1688371214385893078      1             2
# 36  1688371214386063777  1688371214385899379      1             2
# 37  1688371215804852019  1688371215804687301      1             2
# 38  1688371219671476629  1688371219671312224      1             2
# 39  1688371223368835585  1688371223368671235      1             2
#
#     instrument_id action side  depth   price  size  flags  ts_in_delta  \
# 35             32      T    N      0  194.05    50    130       164307
# 36             32      T    N      0  194.05    50    130       164398
# 37             32      T    B      0  194.21    10    130       164718
# 38             32      T    N      0  194.14    10    130       164405
# 39             32      T    B      0  194.13    10    130       164350
#
#     sequence  bid_px_00  ask_px_00  bid_sz_00  ask_sz_00  bid_ct_00  \
# 35    326232      194.0     194.30       3101         19          4
# 36    326233      194.0     194.30       3101         19          4
# 37    328131      194.0     194.21       3101         29          4
# 38    331406      194.0     194.16       3101        400          4
# 39    334235      194.0     194.13       3101        400          4
#
#     ask_ct_00 symbol   Close  Volume    High    Low    Open        RSI  \
# 35         10   AAPL  194.05      50  194.30  194.0  194.05  54.544543
# 36         10   AAPL  194.05      50  194.30  194.0  194.05  54.544543
# 37          1   AAPL  194.21      10  194.21  194.0  194.05  85.890753
# 38          1   AAPL  194.14      10  194.16  194.0  194.21  64.827662
# 39          1   AAPL  194.13      10  194.13  194.0  194.14  62.470772
#
#         MACD  MACD_signal  MACD_hist    Stoch_k    Stoch_d    OBV          AD  \
# 35  0.006271    -0.003130   0.009401  52.525253  61.952862 -266.0 -392.666667
# 36  0.007108    -0.001082   0.008190  38.383838  52.525253 -266.0 -426.000000
# 37  0.020446     0.003223   0.017223  40.404040  43.771044 -256.0 -416.000000
# 38  0.025079     0.007594   0.017484  49.494949  42.760943 -266.0 -408.500000
# 39  0.027625     0.011601   0.016025  57.575758  49.158249 -276.0 -398.500000
#
#       Upper_BB  Middle_BB    Lower_BB  ATR_1     ATR_2     ATR_5    ATR_10  \
# 35  194.065621   194.0170  193.968379   0.30  0.175078  0.098615  0.075141
# 36  194.068990   194.0200  193.971010   0.30  0.237539  0.138892  0.097627
# 37  194.125889   194.0305  193.935111   0.21  0.223770  0.153114  0.108864
# 38  194.142928   194.0375  193.932072   0.21  0.216885  0.164491  0.118978
# 39  194.155247   194.0440  193.932753   0.14  0.178442  0.159593  0.121080
#
#       ATR_20        ADX        +DI       -DI         CCI       DLR  \
# 35  0.072403  97.257397  30.435801  0.196362  166.666667  0.000000
# 36  0.083783  97.361721  22.989295  0.148320   83.333333  0.000000
# 37  0.090094  97.458593  19.409454  0.125224   79.268293  0.000824
# 38  0.096089  97.548546  16.622008  0.107240   -3.205128 -0.000360
# 39  0.098285  97.632074  15.068361  0.097216 -113.095238 -0.000052
#
#           TWAP        VWAP  liquidity  Liquidity_Shock  VWAP_Deviation  \
# 35  194.020000  194.021894  605285.70        -0.004780        0.000145
# 36  194.020811  194.025188  605285.70         0.000000        0.000128
# 37  194.025789  194.025596  607226.09         0.003206        0.000950
# 38  194.028718  194.025873  679258.00         0.118625        0.000588
# 39  194.031250  194.026071  679246.00        -0.000018        0.000536
#
#     Volume_Spike  Institutional_Activity_Ratio  Order_Flow_Imbalance  \
# 35     -0.301676                           0.1                  -355
# 36     -0.313187                           0.1                  -355
# 37     -0.863481                           0.1                  -345
# 38     -0.863760                           0.0                  -345
# 39     -0.863946                           0.0                  -335
#
#     smoothed_ofi                     timestamp
# 35        -438.4 2023-07-03 08:00:14.386057385
# 36        -481.3 2023-07-03 08:00:14.386063777
# 37        -523.3 2023-07-03 08:00:15.804852019
# 38        -482.3 2023-07-03 08:00:19.671476629
# 39        -440.6 2023-07-03 08:00:23.368835585
